# %% [markdown]
# # 04. 판다스 데이터프레임 기초 이

# %% [markdown]
# # 01) 데이터프레임의 출력
#
# - 판다스는 데이터가 위치한 URL을 입력하는 것만으로도 데이터를 바로 읽어오는 기능을 가지고 있음
# - CSV 파일을 데이터프레임으로 읽을 때 pd.read_csv()를 사용

# %% [markdown]
# ## 1. 데이터 로드

# %%
import pandas as pd

url = 'https://raw.githubusercontent.com/justmarkham/DAT8/master/data/drinks.csv'
drink_df = pd.read_csv(url, sep=',')
# read_csv에서 구분자를 직접 넣을 때는 sep= 로 지정
# pd.read_csv(url, ',') 이렇게 쓰면 positional argument 오류 발생
# 기본이 comma 구분

# %%
# drink_df의 타입 확인하기
type(drink_df)
# Out:
# pandas.core.frame.DataFrame

# %%
# drink_df 출력하기
drink_df
# Out:
#          country  beer_servings  spirit_servings  wine_servings  \
# 0    Afghanistan              0                0              0
# 1        Albania             89              132             54
# 2        Algeria             25                0             14
# 3        Andorra            245              138            312
# 4         Angola            217               57             45
# ..           ...            ...              ...            ...
# 188    Venezuela            333              100              3
# 189      Vietnam            111                2              1
# 190        Yemen              6                0              0
# 191       Zambia             32               19              4
# 192     Zimbabwe             64               18              4
#
#      total_litres_of_pure_alcohol continent
# 0                             0.0        AS
# 1                             4.9        EU
# 2                             0.7        AF
# ...

# %% [markdown]
# ## 2. 데이터프레임의 출력

# %%
# head()-> 상위 5개의 행을 출력
drink_df.head()
# Out:
#        country  beer_servings  spirit_servings  wine_servings  \
# 0  Afghanistan              0                0              0
# 1      Albania             89              132             54
# 2      Algeria             25                0             14
# 3      Andorra            245              138            312
# 4       Angola            217               57             45
#
#    total_litres_of_pure_alcohol continent
# 0                           0.0        AS
# 1                           4.9        EU
# 2                           0.7        AF
# 3                          12.4        EU
# 4                           5.9        AF

# %%
# head(숫자) -> 상위 입력한 숫자만큼의 행을 출력
drink_df.head(10)
# Out:
#              country  beer_servings  spirit_servings  wine_servings  \
# 0        Afghanistan              0                0              0
# 1            Albania             89              132             54
# 2            Algeria             25                0             14
# 3            Andorra            245              138            312
# 4             Angola            217               57             45
# 5  Antigua & Barbuda            102              128             45
# 6          Argentina            193               25            221
# 7            Armenia             21              179             11
# 8          Australia            261               72            212
# 9            Austria            279               75            191
#
#    total_litres_of_pure_alcohol continent
# 0                           0.0        AS
# 1                           4.9        EU
# 2                           0.7        AF
# 3                          12.4        EU
# ...

# %%
# tail() -> 하위 5개의 행을 출력
drink_df.tail()
# Out:
#        country  beer_servings  spirit_servings  wine_servings  \
# 188  Venezuela            333              100              3
# 189    Vietnam            111                2              1
# 190      Yemen              6                0              0
# 191     Zambia             32               19              4
# 192   Zimbabwe             64               18              4
#
#      total_litres_of_pure_alcohol continent
# 188                           7.7        SA
# 189                           2.0        AS
# 190                           0.1        AS
# 191                           2.5        AF
# 192                           4.7        AF

# %%
# sample(숫자) -> 랜덤으로 선택된 행을 출력
# 데이터를 눈으로 파악할 때 연속적으로 실행하며 데이터를 파악하기에 좋음
drink_df.sample(10)
# Out:
#                 country  beer_servings  spirit_servings  wine_servings  \
# 171         Timor-Leste              1                1              4
# 54          El Salvador             52               69              2
# 49             Djibouti             15               44              3
# 166         Switzerland            185              100            280
# 93               Latvia            281              216             62
# 72               Guyana             93              302              1
# 39                Congo             76                1              9
# 175             Tunisia             51                3             20
# 128            Pakistan              0                0              0
# 141  Russian Federation            247              326             73
#
#      total_litres_of_pure_alcohol continent
# 171                           0.1        AS
# 54                            2.2       NaN
# 49                            1.1        AF
# ...

# %% [markdown]
# ## 3. 데이터프레임의 인덱스

# %%
# index -> 데이터프레임의 인덱스를 확인
drink_df.index

# 현재 인덱스는 0부터 시작해서 +1씩 증가하여192까지 있음
# 193에서 stop한다는 것은 193은 포함하지 않는다는 의미
# 즉, 0번부터 192번까지의 샘플이 있는 셈이므로 총 샘플의 수는 193개
# Out:
# RangeIndex(start=0, stop=193, step=1)

# %% [markdown]
# ## 4. 데이터프레임의 데이터타입

# %%
# dtypes -> 각 데이터프레임의 열의 타입을 확인할 수 있음
drink_df.dtypes

# 데이터프레임의 타입에서 object -> 문자열
# int64 -> 정수형 데이터
# float64 -> 실수형 데이터

# 출력 결과를 해석해보면
# country, continent 열 -> 문자열 데이터
# beer_servings, spirit_servings, wine_servings 열 -> 정수형 데이터
# total_litres_of_alcohol 열 -> 실수형 데이터

# 이를 통해서 각 열의 데이터 자료형이 무엇인지를 파악할 수 있음
# Out:
# country                          object
# beer_servings                     int64
# spirit_servings                   int64
# wine_servings                     int64
# total_litres_of_pure_alcohol    float64
# continent                        object
# dtype: object

# %% [markdown]
# ## 5. 데이터프레임의 크기

# %%
# shape -> 데이터프레임의 행과 열의 수 확인
drink_df.shape
# Out:
# (193, 6)

# %% [markdown]
# ## 6. 데이터프레임의 행렬 변환

# %%
# values -> 데이터프레임 형태를 Numpy 행렬 형태로 변환하여 출력
drink_df.values
# Out:
# array([['Afghanistan', 0, 0, 0, 0.0, 'AS'],
#        ['Albania', 89, 132, 54, 4.9, 'EU'],
#        ['Algeria', 25, 0, 14, 0.7, 'AF'],
#        ...,
#        ['Yemen', 6, 0, 0, 0.1, 'AS'],
#        ['Zambia', 32, 19, 4, 2.5, 'AF'],
#        ['Zimbabwe', 64, 18, 4, 4.7, 'AF']], dtype=object)

# %%
type(drink_df.values)

# Numpy -> 각각의 행을 데이터프레임의 행 형태에서
# ['Afghanistan', 0, 0, 0, 0.0, 'AS']와 같은 형태로 변환하는 것
# Out:
# numpy.ndarray

# %%
# 변환한 데이터의 첫번째 행 출력
# 0번 인덱스로 접근
drink_df.values[0]
# Out:
# array(['Afghanistan', 0, 0, 0, 0.0, 'AS'], dtype=object)

# %%
# 위와 같은 형태로 변환이 되었다는 것은
# for문 접근도 가능하다는 의미!

for element in drink_df.values[0]:
  print(element)

# *???*
# Out:
# Afghanistan
# 0
# 0
# 0
# 0.0
# AS

# %% [markdown]
# ## 7. 데이터프레임의 info

# %%
# info() -> 데이터프레임의 전반적인 정보를 보여줌
drink_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 193 entries, 0 to 192
# Data columns (total 6 columns):
#  #   Column                        Non-Null Count  Dtype
# ---  ------                        --------------  -----
#  0   country                       193 non-null    object
#  1   beer_servings                 193 non-null    int64
#  2   spirit_servings               193 non-null    int64
#  3   wine_servings                 193 non-null    int64
#  4   total_litres_of_pure_alcohol  193 non-null    float64
#  5   continent                     170 non-null    object
# dtypes: float64(1), int64(3), object(2)
# memory usage: 9.2+ KB

# %% [markdown]
# <info()를 통해 알 수 있는 정보>
#
# - 특성(feature) -> 데이터를 파악하기 위한 열
# - country: 국가
# - beer_servings : 맥주 소비량
# - spiti_servings : spirit 소비량
# - wine_servings : wine 소비량
# - total_litres_of_pure_alcohol : 총 알코올 소비량
# - continent : 대륙 정보
#
# 데이터의 총 개수는 193개인데 Non-Null Count를 보면 continent의 경우에만 170개가 있음
# -> 이는 Null 데이터(결측 데이터)가 23개 존재한다는 것을 의미

# %% [markdown]
# ## 8. 데이터프레임의 결측값(Null)

# %%
# 결측값 = 정상적으로 존재하지 않는 경우의 값
# Null 값이라고도 표현
# isnull().sum() -> 해당 데이터프레임의 각 열에서 Null 데이터가 총 몇 개인지를 출력
print(drink_df.isnull().sum())

# continent 열에서 총 23개의 Null(결측)데이터가 있음을 확
# Out:
# country                          0
# beer_servings                    0
# spirit_servings                  0
# wine_servings                    0
# total_litres_of_pure_alcohol     0
# continent                       23
# dtype: int64

# %% [markdown]
# # 02) 데이터프레임의 열 접근

# %% [markdown]
# ## 1. 데이터 로드

# %%
import pandas as pd

url = 'https://raw.githubusercontent.com/justmarkham/DAT8/master/data/drinks.csv'
drink_df = pd.read_csv(url, sep=',')
drink_df
# Out:
#          country  beer_servings  spirit_servings  wine_servings  \
# 0    Afghanistan              0                0              0
# 1        Albania             89              132             54
# 2        Algeria             25                0             14
# 3        Andorra            245              138            312
# 4         Angola            217               57             45
# ..           ...            ...              ...            ...
# 188    Venezuela            333              100              3
# 189      Vietnam            111                2              1
# 190        Yemen              6                0              0
# 191       Zambia             32               19              4
# 192     Zimbabwe             64               18              4
#
#      total_litres_of_pure_alcohol continent
# 0                             0.0        AS
# 1                             4.9        EU
# 2                             0.7        AF
# ...

# %% [markdown]
# ## 2. 데이터프레임의 열 접근

# %%
# 데이터프레임의이름.열의 이름
# 데이터프레임의 이름을 적고 온점을 찍은 후에 열의 이름을 적으면 해당 열만을 불러옴
drink_df.beer_servings
# Out:
# 0        0
# 1       89
# 2       25
# 3      245
# 4      217
#       ...
# 188    333
# 189    111
# 190      6
# 191     32
# 192     64
# Name: beer_servings, Length: 193, dtype: int64

# %%
# 다른 방법
# 데이터프레임의 이름['해당 열의 이름']
drink_df['beer_servings']
# Out:
# 0        0
# 1       89
# 2       25
# 3      245
# 4      217
#       ...
# 188    333
# 189    111
# 190      6
# 191     32
# 192     64
# Name: beer_servings, Length: 193, dtype: int64

# %% [markdown]
# 2차원 테이블 형태를 데이터프레임이라고 부르지만 이렇게 특정 하나의 열만 불러올 경우에는 데이터프레임이 아니라 데이터 타입이 판다스에서 제공하는 또 다른 데이터 타입인 시리즈가 됨

# %%
# 컬럼의 타입 확인해보기
type(drink_df.beer_servings)
# Out:
# pandas.core.series.Series

# %%
# 선택적으로 다수의 열에 접근하는 방법
# 데이터프레임의 이름[['특정열의 이름1', '특정열의 이름2']]
drink_df[['beer_servings', 'wine_servings']]

# 두 개의 열만 뽑힌 데이터프레임이 출력됨
# ['특정 열의 이름1', '특정 열의 이름2'] -> 파이썬 리스트 형태

# 파이썬 리스트의 형태로 열의 이름을 나열한 뒤에
# 데이터프레임의 이름[열의 이름이 나열된 파이썬 리스트]
# 를 사용해도 동일한결과를 출력
cols = ['beer_servings', 'wine_servings']
drink_df[cols]
# Out:
#      beer_servings  wine_servings
# 0                0              0
# 1               89             54
# 2               25             14
# 3              245            312
# 4              217             45
# ..             ...            ...
# 188            333              3
# 189            111              1
# 190              6              0
# 191             32              4
# 192             64              4
#
# [193 rows x 2 columns]

# %% [markdown]
# # 03) 특성의 수치 정보 파악하기

# %% [markdown]
# ## 1. 데이터 로드

# %%
import pandas as pd

url = 'https://raw.githubusercontent.com/justmarkham/DAT8/master/data/drinks.csv'
drink_df = pd.read_csv(url, sep=',')
drink_df
# Out:
#          country  beer_servings  spirit_servings  wine_servings  \
# 0    Afghanistan              0                0              0
# 1        Albania             89              132             54
# 2        Algeria             25                0             14
# 3        Andorra            245              138            312
# 4         Angola            217               57             45
# ..           ...            ...              ...            ...
# 188    Venezuela            333              100              3
# 189      Vietnam            111                2              1
# 190        Yemen              6                0              0
# 191       Zambia             32               19              4
# 192     Zimbabwe             64               18              4
#
#      total_litres_of_pure_alcohol continent
# 0                             0.0        AS
# 1                             4.9        EU
# 2                             0.7        AF
# ...

# %% [markdown]
# ## 2. 특성(features)

# %%
# info() -> 데이터프레임의 전반적인 정보
drink_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 193 entries, 0 to 192
# Data columns (total 6 columns):
#  #   Column                        Non-Null Count  Dtype
# ---  ------                        --------------  -----
#  0   country                       193 non-null    object
#  1   beer_servings                 193 non-null    int64
#  2   spirit_servings               193 non-null    int64
#  3   wine_servings                 193 non-null    int64
#  4   total_litres_of_pure_alcohol  193 non-null    float64
#  5   continent                     170 non-null    object
# dtypes: float64(1), int64(3), object(2)
# memory usage: 9.2+ KB

# %% [markdown]
# ## 3. 특성의 수치 정보 파악하기

# %%
# 수치 데이터 -> 최솟값, 최댓값, 평균값 등을 파악하는 것이 데이터 파악의 가장 첫 걸음!!
# describe() -> 데이터프레임 형태로 저장된 상황에서 가장 빠르게 파악 가능
drink_df.describe()
# Out:
#        beer_servings  spirit_servings  wine_servings  \
# count     193.000000       193.000000     193.000000
# mean      106.160622        80.994819      49.450777
# std       101.143103        88.284312      79.697598
# min         0.000000         0.000000       0.000000
# 25%        20.000000         4.000000       1.000000
# 50%        76.000000        56.000000       8.000000
# 75%       188.000000       128.000000      59.000000
# max       376.000000       438.000000     370.000000
#
#        total_litres_of_pure_alcohol
# count                    193.000000
# mean                       4.717098
# std                        3.773298
# min                        0.000000
# 25%                        1.300000
# 50%                        4.200000
# 75%                        7.200000
# max                       14.400000

# %% [markdown]
# <describe()>
# - 데이터프레임의총 데이터의 수(count), 평균(mean), 표준편차(std), 분위수(25%, 50%, 75%)를 파악하여 출력
# - 이는 수치 정보에 국한되어서 계산함
# - 문자열 타입의 데이터 열은 제외

# %%
# 특정 열에 대해서만 출력하기
drink_df.beer_servings.describe()
# Out:
# count    193.000000
# mean     106.160622
# std      101.143103
# min        0.000000
# 25%       20.000000
# 50%       76.000000
# 75%      188.000000
# max      376.000000
# Name: beer_servings, dtype: float64

# %%
# 특정 열의 최대값, 최소값, 평균값, 합계, 카운트 계산

# 평균
drink_df.beer_servings.mean()

# 최대값
drink_df.beer_servings.max()

# 최소값
drink_df.beer_servings.min()

# 합계
drink_df.beer_servings.sum()

# 카운트
drink_df.beer_servings.count()
# Out:
# np.int64(193)

# %%
# sum()과 count()를 이용하여 평균 구해보기
float(drink_df.beer_servings.sum()/drink_df.beer_servings.count())
# Out:
# 106.16062176165804

# %% [markdown]
# # 04) 조건부 로직

# %% [markdown]
# ## 1. 데이터 로드

# %%
import pandas as pd

url = 'https://raw.githubusercontent.com/justmarkham/DAT8/master/data/drinks.csv'
drink_df = pd.read_csv(url, sep=',')
drink_df
# Out:
#          country  beer_servings  spirit_servings  wine_servings  \
# 0    Afghanistan              0                0              0
# 1        Albania             89              132             54
# 2        Algeria             25                0             14
# 3        Andorra            245              138            312
# 4         Angola            217               57             45
# ..           ...            ...              ...            ...
# 188    Venezuela            333              100              3
# 189      Vietnam            111                2              1
# 190        Yemen              6                0              0
# 191       Zambia             32               19              4
# 192     Zimbabwe             64               18              4
#
#      total_litres_of_pure_alcohol continent
# 0                             0.0        AS
# 1                             4.9        EU
# 2                             0.7        AF
# ...

# %% [markdown]
# ## 2. 조건부 로직
# - 데이터프레임에 우리가 원하는 조건을 걸어서 해당 조건을 충족하는 값들만 뽑아오는 것도 가능

# %%
# 특정 열에 대해서 조건을 걸었을 때 어떤 값을 반환하는지 보기
# 데이터프레임의 이름.특정 열의 이름 == '특정값'

# -> 각 행에서 해당 조건을 만족하는지를 판단하여 만족한다면
# True
# 아니라면
# False의 값을 가지는 시리즈를 리턴

drink_df.continent == 'EU'
# Out:
# 0      False
# 1       True
# 2      False
# 3       True
# 4      False
#        ...
# 188    False
# 189    False
# 190    False
# 191    False
# 192    False
# Name: continent, Length: 193, dtype: bool

# %% [markdown]
# - 하지만 일반적으로 저런 조건을 걸었을 때 우리가 원하는 건 True와 False로 구성된 시리즈가 아니라 continent의 값이 'EU'일 때의 데이터프레임 값을 뽑아내는 것임
# - 이 경우에는 True와 False로 구성된 Series를 다음과 같이 사용해주면 됨

# %%
# 데이터프레임의 이름[True와 False로 구성된 시리즈]

# 일단 drink_df.continent=='EU'의 타입이 시리즈임을 확인하기
type(drink_df.continent=='EU')

# 이를 데이터프레임의 이름[]의 대괄호 안에 넣기
# head(20)을 이용하여 상위 20개만 출력
drink_df[drink_df.continent=='EU'].head(20)
# Out:
#                country  beer_servings  spirit_servings  wine_servings  \
# 1              Albania             89              132             54
# 3              Andorra            245              138            312
# 7              Armenia             21              179             11
# 9              Austria            279               75            191
# 10          Azerbaijan             21               46              5
# 15             Belarus            142              373             42
# 16             Belgium            295               84            212
# 21  Bosnia-Herzegovina             76              173              8
# 25            Bulgaria            231              252             94
# 42             Croatia            230               87            254
# 44              Cyprus            192              154            113
# 45      Czech Republic            361              170            134
# ...

# %%
# beer_servings의 값이 158보다 큰 경우로 필터링 하는 코드
# drink_df[drink_df.beer_servings > 158]
# drink_df[drink_df['beer_servings'] > 158]

drink_df[drink_df['beer_servings'] > 158].head(20)
# Out:
#                country  beer_servings  spirit_servings  wine_servings  \
# 3              Andorra            245              138            312
# 4               Angola            217               57             45
# 6            Argentina            193               25            221
# 8            Australia            261               72            212
# 9              Austria            279               75            191
# 16             Belgium            295               84            212
# 17              Belize            263              114              8
# 20             Bolivia            167               41              8
# 22            Botswana            173               35             35
# 23              Brazil            245              145             16
# 25            Bulgaria            231              252             94
# 32              Canada            240              122            100
# ...

# %% [markdown]
# <조건을 걸고 특정 열 몇 개만 출력하기>
# - 특정 열들만 뽑아서 출력하는 방법-> 데이터프레임의 이름[['특정 열의 이름1, '특정 열의 이름2']]

# %%
# 이를 응용
# beer_servings의 값이 10이하이면서
# country, beer_servings의 두 개의 열만을 뽑아내기

# drink_df[drink_df.beer_servings <= 10]로 조건에 맞는 데이터프레임을 뽑아낸 뒤에
# 이 데이터프레임에 [['country','beer_servings']]를 붙여서 2개의 열만을 뽑아내기
drink_df[drink_df.beer_servings <= 10][['country','beer_servings']].head(20)
# Out:
#               country  beer_servings
# 0         Afghanistan              0
# 13         Bangladesh              0
# 38            Comoros              1
# 40       Cook Islands              0
# 46        North Korea              0
# 53              Egypt              6
# 63             Gambia              8
# 70             Guinea              9
# 73              Haiti              1
# 77              India              9
# 78          Indonesia              5
# 79               Iran              0
# 80               Iraq              9
# 86             Jordan              6
# 90             Kuwait              0
# 97              Libya              0
# 101            Malawi              8
# 103          Maldives              0
# 104              Mali              5
# 106  Marshall Islands              0

# %%
# 조건으로 필터링하여시리즈를 얻어낸 뒤에 평균구하기
drink_df[drink_df.continent=='EU'].beer_servings.mean()

# *???*
# Out:
# np.float64(193.77777777777777)

# %% [markdown]
# - 위 코드는 continent의 값이 'EU'인 경우로 데이터프레임으로 뽑아내지만 그 중 beer_servings라는 하나의 열만을 뽑아냄
# - 열을 하나만 뽑을 경우 데이터프레임이 아니라 시리즈가 됨
# - 따라서 시리즈로 변환되며 시리즈에 대해서 mean()을 사용하여 평균값을 뽑아내게 됨
# - 결과적으로 continent의 값이 EU인 beer_servings열의 평균값을 구하게 됨

# %%
# beer_servings열의 평균값을 조건에 넣어보기
drink_df[drink_df.beer_servings > drink_df.beer_servings.mean()]
# Out:
#             country  beer_servings  spirit_servings  wine_servings  \
# 3           Andorra            245              138            312
# 4            Angola            217               57             45
# 6         Argentina            193               25            221
# 8         Australia            261               72            212
# 9           Austria            279               75            191
# ..              ...            ...              ...            ...
# 182  United Kingdom            219              126            195
# 184             USA            249              158             84
# 185         Uruguay            115               35            220
# 188       Venezuela            333              100              3
# 189         Vietnam            111                2              1
#
#      total_litres_of_pure_alcohol continent
# 3                            12.4        EU
# 4                             5.9        AF
# ...

# %% [markdown]
# isnull()
# - 해당 열에 null값이 존재하는지 유무에 대한 True, False의 시리즈로 얻어내는 방법
# - 해당 항에 Null 값이 들어있는 경우만 True를 리턴하고 아니라면 False를 리턴

# %%
drink_df.continent.isnull()

drink_df.continent.isnull().sum()
# Out:
# np.int64(23)

# %%
# 데이터프레임에서 특정 열에 Null값이 위치한 경우만 뽑을 수 있음
drink_df[drink_df.continent.isnull()]
# Out:
#                           country  beer_servings  spirit_servings  \
# 5               Antigua & Barbuda            102              128
# 11                        Bahamas            122              176
# 14                       Barbados            143              173
# 17                         Belize            263              114
# 32                         Canada            240              122
# 41                     Costa Rica            149               87
# 43                           Cuba             93              137
# 50                       Dominica             52              286
# 51             Dominican Republic            193              147
# 54                    El Salvador             52               69
# 68                        Grenada            199              438
# 69                      Guatemala             53               69
# 73                          Haiti              1              326
# ...

# %%
len(drink_df[drink_df.continent.isnull()])

# continent의 값에 NaN값인 경우만 출력되는 것을 확인할 수 있음
# Out:
# 23

# %% [markdown]
# # 05) AND, OR, NOT 연산자 사용하기
# - 참고: https://wikidocs.net/22211

# %% [markdown]
# ## 01) 데이터 로드

# %%
import pandas as pd

url = 'https://raw.githubusercontent.com/justmarkham/DAT8/master/data/drinks.csv'
drink_df = pd.read_csv(url, sep=',')
drink_df
# Out:
#          country  beer_servings  spirit_servings  wine_servings  \
# 0    Afghanistan              0                0              0
# 1        Albania             89              132             54
# 2        Algeria             25                0             14
# 3        Andorra            245              138            312
# 4         Angola            217               57             45
# ..           ...            ...              ...            ...
# 188    Venezuela            333              100              3
# 189      Vietnam            111                2              1
# 190        Yemen              6                0              0
# 191       Zambia             32               19              4
# 192     Zimbabwe             64               18              4
#
#      total_litres_of_pure_alcohol continent
# 0                             0.0        AS
# 1                             4.9        EU
# 2                             0.7        AF
# ...

# %% [markdown]
# ## 2. AND, OR, NOT 연산자 사용하기
# - AND나 OR 또는 NOT과 같은 연산자를 사용하여 여러 개의 조건을 동시에 사용하거나 조건문 자체를 반대로 해석하도록 할 수 있음
# ---
# - & : AND
# - | : OR
# - ~ : NOT
# ---
# - A조건 & B조건 : A조건과 B조건 모두 만족하는 경우
# - A조건 | B조건 : A조건 또는 B조건 둘 중 하나를 만족하는 경우
# - ~A조건 : A조건을 만족하는 경우의 반대. 즉, A조건을 만족하지 않는 경우

# %%
# NOT
drink_df[~(drink_df.continent=='EU')]

# continent의 값이 'EU'가 아닌 경우만을 필터링
# Out:
#                country  beer_servings  spirit_servings  wine_servings  \
# 0          Afghanistan              0                0              0
# 2              Algeria             25                0             14
# 4               Angola            217               57             45
# 5    Antigua & Barbuda            102              128             45
# 6            Argentina            193               25            221
# ..                 ...            ...              ...            ...
# 188          Venezuela            333              100              3
# 189            Vietnam            111                2              1
# 190              Yemen              6                0              0
# 191             Zambia             32               19              4
# 192           Zimbabwe             64               18              4
#
#      total_litres_of_pure_alcohol continent
# 0                             0.0        AS
# ...

# %%
# AND
drink_df[(drink_df.continent=='EU') & (drink_df.wine_servings > 300)]

# continent의 값이 'EU'이면서 wine_servings의 값이 300보다 큰 경우만을 필터링
# Out:
#       country  beer_servings  spirit_servings  wine_servings  \
# 3     Andorra            245              138            312
# 61     France            127              151            370
# 136  Portugal            194               67            339
#
#      total_litres_of_pure_alcohol continent
# 3                            12.4        EU
# 61                           11.8        EU
# 136                          11.0        EU

# %%
# OR
drink_df[(drink_df.continent=='EU') | (drink_df.wine_servings > 300)]

# len(입력) -> 입력의 길이를 계산하여 알려줌
# 데이터프레임의 이름을 입력으로 할 경우에는 데이터프레임의 행의 길이를 출력
len(drink_df[(drink_df.continent=='EU') | (drink_df.wine_servings > 300)])
# Out:
# 45

# %% [markdown]
# # 06) 로직과 수치 정보의 결합 & 정렬

# %% [markdown]
# ## 1. 데이터 로드

# %%
import pandas as pd

url = 'https://raw.githubusercontent.com/justmarkham/DAT8/master/data/drinks.csv'
drink_df = pd.read_csv(url, sep=',')
drink_df
# Out:
#          country  beer_servings  spirit_servings  wine_servings  \
# 0    Afghanistan              0                0              0
# 1        Albania             89              132             54
# 2        Algeria             25                0             14
# 3        Andorra            245              138            312
# 4         Angola            217               57             45
# ..           ...            ...              ...            ...
# 188    Venezuela            333              100              3
# 189      Vietnam            111                2              1
# 190        Yemen              6                0              0
# 191       Zambia             32               19              4
# 192     Zimbabwe             64               18              4
#
#      total_litres_of_pure_alcohol continent
# 0                             0.0        AS
# 1                             4.9        EU
# 2                             0.7        AF
# ...

# %% [markdown]
# drink_df에서 total_litres_of_pure_alchohol의 값이 최대값인 경우의 country 열을 출력한다면?
# - 특정 열의 최대값을 구하는 방법?
# - 특정 열만을 출력하는 방법?

# %%
# total_litres_of_pure_alchohol의 값이 가장 큰 나라 구하기
drink_df[drink_df.total_litres_of_pure_alcohol == drink_df.total_litres_of_pure_alcohol.max()]['country']
# Out:
# 15    Belarus
# Name: country, dtype: object

# %% [markdown]
# drink_df에서 wine_servings의 값이 300보다 크거나 beer_servings의 값이 300보다 크거나 spirit_servings의 값이 300보다 큰 경우의 country열의 데이터를 모두 카운트하였을 때의 숫자를 출력
# - 다수의 조건을 '또는'으로 한 번에 사용하는 방법?
# - 숫자를 '카운트' 하는 방법?

# %%
drink_df[(drink_df.wine_servings > 300) | (drink_df.beer_servings > 300) | (drink_df.spirit_servings > 300)].country.count()
# Out:
# np.int64(18)

# %% [markdown]
# ## 3. 정렬
# - 데이터를 특정 기준으로 정렬해서 볼 수 있음

# %%
# 데이터프레임의 이름.sort_values('정렬 기준이 되는 열의 이름')
drink_df.sort_values('beer_servings')

# beer_servings의 열이 오름차순으로 정렬된 것을 확인할 수 있음
# 기본적으로는 오름차순으로 정렬

# 내림차순으로 정렬하고 싶으면
# 데이터프레임의 이름.sort_values('정렬 기준이 되는 열의 이름', ascending=False)
# sort_values의 인자로 ascending=False를 추가
drink_df.sort_values('beer_servings', ascending=False)
# Out:
#             country  beer_servings  spirit_servings  wine_servings  \
# 117         Namibia            376                3              1
# 45   Czech Republic            361              170            134
# 62            Gabon            347               98             59
# 65          Germany            346              117            175
# 98        Lithuania            343              244             56
# ..              ...            ...              ...            ...
# 97            Libya              0                0              0
# 103        Maldives              0                0              0
# 158         Somalia              0                0              0
# 147      San Marino              0                0              0
# 149    Saudi Arabia              0                5              0
#
#      total_litres_of_pure_alcohol continent
# 117                           6.8        AF
# 45                           11.8        EU
# ...

# %%
# 정렬의 기준은 하나의 열이 아니라 다수의 열일 수 있음
# 열의 이름들을 원소로하는 리스트를 sort_values의 입력으로 사용
# 해당 열들을 기준으로 정렬
drink_df.sort_values(['beer_servings', 'wine_servings'])
# Out:
#             country  beer_servings  spirit_servings  wine_servings  \
# 0       Afghanistan              0                0              0
# 13       Bangladesh              0                0              0
# 46      North Korea              0                0              0
# 79             Iran              0                0              0
# 90           Kuwait              0                0              0
# ..              ...            ...              ...            ...
# 135          Poland            343              215             56
# 65          Germany            346              117            175
# 62            Gabon            347               98             59
# 45   Czech Republic            361              170            134
# 117         Namibia            376                3              1
#
#      total_litres_of_pure_alcohol continent
# 0                             0.0        AS
# 13                            0.0        AS
# ...

# %% [markdown]
# # 07) 상관 관계 분석
# ### 상관분석
# - 두 변수 간의 선형적 관계를 상관 계수로 표현하는 것
# - 상관 계수를 구하는 것은 공분산의 개념을 포함
# - 공분산은 2개의 변수에 대한 상관 정도(2개의 변수 중 하나의 값이 상승하는 경향을 보이면 다른 값도 상승하는 경향을 수치로 표현한 것)
# - 하지만 공분산만으로 두 확률 변수의 상관 관계를 구한다면 두 변수의 단위 크기에 영향을 받을 수 있음
# - 따라서 이를 -1과 1사이 값으로 변환
# - 이를 상관 계수라고함
#   - 상관 계수가 1에 가까움 -> 서로 강한 양의 상관 관계가 있는 것
#   - -1에 가까움 -> 음의 상관 관계가 있는 것
#   - 0 -> 상관 관계가 없음
# ---
# ### Matplotlib
# - 파이썬에서 자료를 차트나 플롯으로 시각화하는 패키지
# ### Seaborn
# - Matplotlib 기반으로 다양한 테마와 기능을 추가한 시각화 패키지

# %% [markdown]
# ## 1. 상관관계 분석

# %%
# 실습을 위해 데이터프레임 임의로 하나 만들기
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# 다수의 파이썬 리스트를 통해 데이터프레임 만들기
# pd.DataFrame({"열이름1":리스트1, "열이름2":리스트2, "열이름3":리스트3})
test_df = pd.DataFrame({"v1":[100,200,300,400], "v2":[400,200,100,250], "v3":[40,60,60,100]})
test_df
# Out:
#     v1   v2   v3
# 0  100  400   40
# 1  200  200   60
# 2  300  100   60
# 3  400  250  100

# %%
# 상관계수 구하기
# 데이터프레임의 이름.corr(method='pearson')
corr = test_df.corr(method = 'pearson')
corr
# Out:
#           v1        v2        v3
# v1  1.000000 -0.568038  0.923381
# v2 -0.568038  1.000000 -0.291397
# v3  0.923381 -0.291397  1.000000

# %% [markdown]
# ## 2. 히트맵 그리기
# - 일반적으로 상관계수 차트를 그릴 때는 seaborn에서 제공하는 heatmap()을 주로 사용함
# ---
# - 각종 설정값이 어떻게 동작하는지 가장 쉽게 알 수 있는 방법은 해당 설정값을 지워서 재출력해보는 것
# - 예) fmt = '.2f'의 값을 fmt = '.3f'으로 바꿔서 재실행
#   - 그러면 차트 위의 숫자가 소수점 셋 째자리까지 출력 될 것임

# %%
# .values -> 데이터프레임의 각 행이 리스트 형태로 변환되어서 출력이 됨
corr.values
# Out:
# array([[ 1.        , -0.56803756,  0.92338052],
#        [-0.56803756,  1.        , -0.29139712],
#        [ 0.92338052, -0.29139712,  1.        ]])

# %%
# 차트에 이름을 입력하기 위해서 column_names리스트 만들기
column_names = ['ver1', 'ver2', 'ver3']

# %%
# sns.heatmap(데이터프레임의 상관계수 데이터)

sns.set(font_scale=2.0) # 레이블의 폰트 사이즈 조정

test_heatmap = sns.heatmap(corr.values, # 데이터
                          cbar = False, # 오른쪽 컬러 막대 출력 여부
                           annot = True, # 차트에 숫자를 보여줄 것인지 여부
                          annot_kws={'size' : 20}, # 숫자 출력 시 숫자 크기 조절
                           fmt = '.2f', # 숫자의 출력 소수점자리 개수 조절
                           square = 'True', # 차트를 정사각형으로 할 것인지
                          yticklabels=column_names, # y축에 컬럼명 출력
                          xticklabels=column_names) # x축에 컬럼명 출력
plt.tight_layout()
plt.show()

# %%
# cbar를 True로 해보기
sns.set(font_scale=2.0)

test_heatmap = sns.heatmap(corr.values,
                           cbar = True,
                           annot = True,
                           annot_kws={'size' : 20},
                           fmt = '.2f',
                           square = True,
                          yticklabels=column_names,
                          xticklabels=column_names)
plt.tight_layout()
plt.show()

# %% [markdown]
# <산점도>
# - 산점도 = 좌표상에 점들을 표시하는 방법
# - 두 개 변수 간의 관계를 나타내는 그래프
# - 변수 A가 증가할 때 변수 B 또한 증가하는 어떤 상관 관계가 있는지
# - 아니면 아무런 관계가 없는지 산점도를 통해서 확인해 볼 수 있음

# %%
# pairplot -> 각 열의 조합에 대해서 산점도를 그리고
# 같은 데이터가 만나는 대각선 영역에는 해당 데이터의 히스토그램을 그림

# sns.pairplot(데이터프레임)
sns.set(style='whitegrid')  # whitegrid = 배경에 하얀 선을 넣음
sns.pairplot(test_df)
plt.show()

# 지금은 데이터가 너무 적어서 산점도를 해석하기에는 무리가 있음

# %% [markdown]
# # 08) 응용! 상관 관계 분석과 산점도

# %% [markdown]
# ## 1. 데이터 로드

# %%
import pandas as pd

url = 'https://raw.githubusercontent.com/justmarkham/DAT8/master/data/drinks.csv'
drink_df = pd.read_csv(url, sep=',')
drink_df
# Out:
#          country  beer_servings  spirit_servings  wine_servings  \
# 0    Afghanistan              0                0              0
# 1        Albania             89              132             54
# 2        Algeria             25                0             14
# 3        Andorra            245              138            312
# 4         Angola            217               57             45
# ..           ...            ...              ...            ...
# 188    Venezuela            333              100              3
# 189      Vietnam            111                2              1
# 190        Yemen              6                0              0
# 191       Zambia             32               19              4
# 192     Zimbabwe             64               18              4
#
#      total_litres_of_pure_alcohol continent
# 0                             0.0        AS
# 1                             4.9        EU
# 2                             0.7        AF
# ...

# %% [markdown]
# ## 2. 주류 데이터의 상관 계수
# - 주류 데이터의 각 특성에 대해서 상관계수를 계산
# - 이를 seaborn의 heatmap과 pairplot을 통해서 시각화해보기

# %%
# 'beer_servings', 'wine_servings' 두 특성 간의 상관계수 계산해보기
corr = drink_df[['beer_servings', 'wine_servings']].corr(method = 'pearson')
corr
# Out:
#                beer_servings  wine_servings
# beer_servings       1.000000       0.527172
# wine_servings       0.527172       1.000000

# %%
# 피처간의 상관계수 행렬 구하기
cols = ['beer_servings', 'spirit_servings', 'wine_servings', 'total_litres_of_pure_alcohol']
corr = drink_df[cols].corr(method = 'pearson')
corr

# 가장 상관계수 값이 높은 경우는 beer_servings와 total_litres_of_pure_alcohold의 상관계수 값으로 0.835839에 해당
# 이를 seaborn의 heatmap을 통해서 시각화해보기

# *???*
# Out:
#                               beer_servings  spirit_servings  wine_servings  \
# beer_servings                      1.000000         0.458819       0.527172
# spirit_servings                    0.458819         1.000000       0.194797
# wine_servings                      0.527172         0.194797       1.000000
# total_litres_of_pure_alcohol       0.835839         0.654968       0.667598
#
#                               total_litres_of_pure_alcohol
# beer_servings                                     0.835839
# spirit_servings                                   0.654968
# wine_servings                                     0.667598
# total_litres_of_pure_alcohol                      1.000000

# %%
# 우선 heatmap의 입력을 만들기 위해서 상관계수 값에 .values를 적용시키기
corr.values

# *???*
# Out:
# array([[1.        , 0.45881887, 0.52717169, 0.83583863],
#        [0.45881887, 1.        , 0.19479705, 0.65496818],
#        [0.52717169, 0.19479705, 1.        , 0.66759834],
#        [0.83583863, 0.65496818, 0.66759834, 1.        ]])

# %%
# 히트맵 차트의 x축과 y축에 각각의 레이블을 달아주기 위해
# 리스트를 만들기
column_names = ['beer', 'spirit', 'wine', 'alcohol']

# %%
# heatmap 시각화
import seaborn as sns
import matplotlib.pyplot as plt

sns.set(font_scale=1.5)
hm = sns.heatmap(corr.values,
            cbar=True,
            annot=True,
            square=True,
            fmt='.2f',
            annot_kws={'size': 15},
            yticklabels=column_names,
            xticklabels=column_names)

plt.tight_layout()
plt.show()

# %% [markdown]
# - cbar -> 오른쪽에 있는 막대(범주)를 표시
# - annot -> 상관계수를 표시
# - square -> 정사각형으로 지정(False로 설정 시 직사각형이 됨)
# - fmt -> 상관계수의 소수점 자리수를 지정
# - annot_kws -> 상관계수의 글자 크기를 지정
# - yticklabels -> y축 레이블 값을 의미
# - xticklabels -> x축 레이블 값을 의미
# ---
# - alcohol은 대체적으로 다른 특성들과 모두 상관 계수가 높음
# - 이미 시각화를 진행하기 전에도 확인한 내용이기는 하지만 그 중에서도 0.84로 beer와 상관 계수값이 가장 높음
# - 앞서 확인하였을 때는 0.835839였지만 여기서는 소수점 두 자리까지만 출력하면서 반올림되어 0.84로 출력
# ---
# <피어슨의 상관계수>
# - -1.0 ~ -0.7 -> 뚜렷한 음적 상관관계
# - -0.3 ~ -0.1 -> 약한 음적 상관관계
# - -0.1 ~ +0.1 -> 없다고 할 수 있는 상관관계
# - +0.1 ~ +0.3 -> 약한 양적 상관관계
# - +0.3 ~ +0.7 -> 뚜렷한 양적 상관관계
# - +0.7 ~ +1.0 -> 강한 양적 상관관계

# %% [markdown]
# ## 3. 산점도
# - 주류 데이터의 산점도(pairplot)를 확인
# - pairplot -> 데이터프레임을 인수로 받아 그리드 형태로 각 데이터 열의 조합에 대해 산점도를 그림
# - 같은 데이터가 만나는 대각선 영역에는 해당 데이터의 히스토그램을 그림

# %%
sns.set(style='whitegrid')
sns.pairplot(drink_df[['beer_servings', 'spirit_servings',
                     'wine_servings', 'total_litres_of_pure_alcohol']])
plt.show()

# %% [markdown]
# # 09) 데이터 탐색하기(결측값 제거, 시각화, 통계 확인)

# %% [markdown]
# ## 1. 데이터 로드

# %%
import pandas as pd

url = 'https://raw.githubusercontent.com/justmarkham/DAT8/master/data/drinks.csv'
drink_df = pd.read_csv(url, sep=',')
drink_df
# Out:
#          country  beer_servings  spirit_servings  wine_servings  \
# 0    Afghanistan              0                0              0
# 1        Albania             89              132             54
# 2        Algeria             25                0             14
# 3        Andorra            245              138            312
# 4         Angola            217               57             45
# ..           ...            ...              ...            ...
# 188    Venezuela            333              100              3
# 189      Vietnam            111                2              1
# 190        Yemen              6                0              0
# 191       Zambia             32               19              4
# 192     Zimbabwe             64               18              4
#
#      total_litres_of_pure_alcohol continent
# 0                             0.0        AS
# 1                             4.9        EU
# 2                             0.7        AF
# ...

# %% [markdown]
# ## 2. 결측값 제거
# - 결측값 = 탐색적 데이터 분석에서도 그 후 더 나아가 머신 러닝 알고리즘을 통해 분석을 할 때에도 성능에 영향을 줄 수 있는 값
#   - (1) 아예 제거를 하기
#     - dropna()
#   - (2) 특정값으로 채워주기
#     - fillna()

# %%
# 앞서 continent열에 결측값이 23개가 있는 것을 확인
# fillna() 사용해보기
# 기타 값이라는 의미에서 'ETC'를 넣어주기
drink_df['continent'] = drink_df['continent'].fillna('ETC')
drink_df.sample(10)

# continent열에 결측값이 있을 경우 'ETC'라는 값으로 채우도록 함
# Out:
#           country  beer_servings  spirit_servings  wine_servings  \
# 36          China             79              192              8
# 151        Serbia            283              131            127
# 54    El Salvador             52               69              2
# 94        Lebanon             20               55             31
# 19         Bhutan             23                0              0
# 172          Togo             36                2             19
# 82         Israel             63               69              9
# 120   Netherlands            251               88            190
# 43           Cuba             93              137              5
# 149  Saudi Arabia              0                5              0
#
#      total_litres_of_pure_alcohol continent
# 36                            5.0        AS
# 151                           9.6        EU
# 54                            2.2       ETC
# 94                            1.9        AS
# ...

# %%
# 결측값이 사라졌는지 확인학
# isnull().sum()
drink_df.isnull().sum()

# 이제 continent열에 결측값이 존재하지 않음
# Out:
# country                         0
# beer_servings                   0
# spirit_servings                 0
# wine_servings                   0
# total_litres_of_pure_alcohol    0
# continent                       0
# dtype: int64

# %% [markdown]
# ## 3. 파이차트 그리기
# 파이차트를 그리려면 이 두 가지가 필요함
# - 파이 차트로 사용할 데이터의 이름이 담긴 리스트
# - 해당 이름에 해당하는 데이터의 값이 담긴 리스트
# ---
# 여기서는
# - continent에 대해서 파이차트 그려볼 것
# - 파이 차트의 값으로는 continent에 있는 각 값들의 개수를 사용

# %%
# continent 열에 대해서 타입 확인
# value_counts()
drink_df['continent'].value_counts()

type(drink_df['continent'].value_counts())

# *???*
# Out:
# pandas.core.series.Series

# %%
# 인덱스에는 continents의 이름,
# 실제 값 부분에는 해당 continents에 있는 값들을 각각 카운트한 값이 들어가 있음

# 인덱스는 index로 접근
# 값에 대해서는 values로 접근

# 각각 접근 후에 리스트로 값을 변화하는 tolist()를 사용

pie_labels = drink_df['continent'].value_counts().index.tolist()
pie_values = drink_df['continent'].value_counts().values.tolist()
print(pie_labels)
print(pie_values)

# *???*
# Out:
# ['AF', 'EU', 'AS', 'ETC', 'OC', 'SA']
# [53, 45, 44, 23, 16, 12]

# %%
# 파이차트 그리기
# plt.pie()
# plt.pie(데이터의 실질적인 값, labels=데이터의 레이블 리스트)

plt.pie(pie_values, labels=pie_labels, autopct='%.02f%%') # autopct -> 소수점을 몇 개까지 출력할지
plt.title('Percentage of each continent')
plt.show()

# %% [markdown]
# ## 4. GroupBy를 이용한 통계 확인
# - Group By = 특정 값을 기준으로 그룹핑한 후에 그룹 별로 통계적인 수치 정보를 구할 수 있도록 하는 방법

# %%
# 데이터프레임의 이름.groupby('그룹핑 기준이 되는 열')['보고자 하는 열'].통계 함수

# 어떤 대륙이 평균적으로 맥주를 더 먹을까?
# 대륙에 대한 열 -> continent
# 맥주의 소비량 -> beer_servings

# 평균을 구하는 함수 -> mean()

drink_df.groupby('continent')['beer_servings'].mean()
# Out:
# continent
# AF      61.471698
# AS      37.045455
# ETC    145.434783
# EU     193.777778
# OC      89.687500
# SA     175.083333
# Name: beer_servings, dtype: float64

# %%
type(drink_df.groupby('continent')['beer_servings'].mean())
# Out:
# pandas.core.series.Series

# %%
# 각 대륙별로 와인 소비에 대한 통계 정보 출력하기
drink_df.groupby('continent')['wine_servings'].describe()
# Out:
#            count        mean        std  min   25%    50%     75%    max
# continent
# AF          53.0   16.264151  38.846419  0.0   1.0    2.0   13.00  233.0
# AS          44.0    9.068182  21.667034  0.0   0.0    1.0    8.00  123.0
# ETC         23.0   24.521739  28.266378  1.0   5.0   11.0   34.00  100.0
# EU          45.0  142.222222  97.421738  0.0  59.0  128.0  195.00  370.0
# OC          16.0   35.625000  64.555790  0.0   1.0    8.5   23.25  212.0
# SA          12.0   62.416667  88.620189  1.0   3.0   12.0   98.50  221.0

# %%
# 모든 컬럼에 대해서 대륙별로 평균 알콜 소비량을 출력하기
# drink_df.groupby('continent').mean()
# => 문자열 컬럼 때문에 오류 발생 -> numeric_only=True로 숫자 컬럼만 평균

# 문자열 컬럼 제외하고 숫자 컬럼만 평균 계산
drink_df.groupby('continent').mean(numeric_only=True)
# Out:
#            beer_servings  spirit_servings  wine_servings  \
# continent
# AF             61.471698        16.339623      16.264151
# AS             37.045455        60.840909       9.068182
# ETC           145.434783       165.739130      24.521739
# EU            193.777778       132.555556     142.222222
# OC             89.687500        58.437500      35.625000
# SA            175.083333       114.750000      62.416667
#
#            total_litres_of_pure_alcohol
# continent
# AF                             3.007547
# AS                             2.170455
# ETC                            5.995652
# EU                             8.617778
# OC                             3.381250
# SA                             6.308333

# %%
# 전체 평균보다 많은 알코올을 섭취하는 대륙 구해보기
total_mean = drink_df.total_litres_of_pure_alcohol.mean()
continent_mean = drink_df.groupby('continent')['total_litres_of_pure_alcohol'].mean()
continent_over_mean = continent_mean[continent_mean >= total_mean]
print(continent_over_mean)
# Out:
# continent
# ETC    5.995652
# EU     8.617778
# SA     6.308333
# Name: total_litres_of_pure_alcohol, dtype: float64

# %%
# 평균 wine_servings이 가장 높은 대륙 구해보기
beer_continent = drink_df.groupby('continent').wine_servings.mean().idxmax()
print(beer_continent)
# Out:
# EU
