# %% [markdown]
# # 01. Matplotlib 기본 사용

# %% [markdown]
# # pyplot 소개
#
# 명령어 스타일로 동작하는 함수의 모음
#
# 용도: 그래프 영역을 만들고, 몇 개의 선을 표현하고, 레이블로 꾸미기

# %% [markdown]
# ### 기본 그래프 그리기

# %%
import matplotlib.pyplot as plt

plt.plot([1, 2, 3, 4]) # y값을 작성한 것, x값은 0, 1, 2, 3을 자동 지정
plt.show()

# %%
import matplotlib.pyplot as plt

plt.plot([1, 2, 3, 4], (1, 4, 9, 16)) # x, y값 둘다 지정
plt.show()

# %% [markdown]
# ### 스타일 지정하기

# %%
import matplotlib.pyplot as plt

plt.plot([1, 2, 3, 4], (1, 4, 9, 16), 'ro') # ro (f-str) = red o (빨간 점)
plt.axis([0, 6, 0, 20]) # axis([xmin, xmax, ymin, ymax]) 지정 가능
plt.show()

# %%
import matplotlib.pyplot as plt

plt.plot([1, 2, 3, 4], (1, 4, 9, 16), 'bo') # bo (f-str) = blue o (파란 점?)
plt.axis([0, 10, 0, 30]) # x 값 최대 = 10, y 값 최대 = 30
plt.show()

# %% [markdown]
# ### 여러 개의 그래프 그리기

# %%
import matplotlib.pyplot as plt
import numpy as np

# 200ms 간격으로 균일하게 계산된 시간
t = np.arange(0., 5., 0.2) # numpy 어레이를 일반적으로 활용한다!
# 고난과 역경(왜 0, 5가 아니라 0., 5. 이라고 작성해야 하는걸까?)

# 빨간 대쉬, 파란 사각형, 녹색 삼각형
plt.plot(t, t, 'r--', t, t**2, 'bs', t, t**3, 'g^') # --:대쉬, s:사각, ^:삼각
plt.show()

# %% [markdown]
# # 02. Matplotlib 숫자 입력하기

# %% [markdown]
# ### 기본사용

# %%
import matplotlib.pyplot as plt

plt.plot([2, 3, 5, 10]) # 하나만 적는다면 다 y-values 취급
# x-values는? 자동으로 0,1,2 이렇게 0부터 1씩 늘어난다(base)
plt.show()

# %%
# 위처럼 파이선 튜플도 가능하지만, <<-- 튜플 "(고난과 역경)"
plt.plot(np.array([2, 3, 5, 10]))  # Numpy 어레이의 형태로도 가능
plt.show()

# %% [markdown]
# ### x, y 값 입력하기

# %%
import matplotlib.pyplot as plt

plt.plot([1, 2, 3, 4], [2, 3, 5, 10]) # 두 개의 리스트를 입력하면 순차적으로 x, y 취급
plt.show()

# %% [markdown]
# ### 레이블이 있는 데이터 사용하기

# %%
import matplotlib.pyplot as plt

data_dict = {'data_x': [1, 2, 3, 4, 5], 'data_y': [2, 3, 5, 10, 8]}
# 파이썬 딕셔너리와 같이 레이블(고난과 역경)이 있는 데이터를 그래프로 나타낼 수 있음

plt.plot('data_x', 'data_y', data=data_dict)
# 먼저 plot() 함수에 데이터의 레이블(딕셔너리의 키)을 입력해주고,
# data 파라미터에 딕셔너리를 지정해줍니다.

plt.show()

# %% [markdown]
# # 03. Matplotlib 축 레이블 설정하기

# %% [markdown]
# ### 기본 사용

# %%
import matplotlib.pyplot as plt

plt.plot([1, 2, 3, 4], [1, 4, 9, 16])
plt.xlabel('X-Label')
plt.ylabel('Y-Label')
# xlabel(), ylabel() 함수에 문자열을 입력하면, 아래 그림과 같이 각각의 축에 레이블이 표시됩니다.
plt.show()

# %% [markdown]
# ### 여백 지정하기

# %%
import matplotlib.pyplot as plt

plt.plot([1, 2, 3, 4], [2, 3, 5, 10])
plt.xlabel('X-Axis', labelpad=15) #  labelpad 파라미터는 축 레이블의 여백 지정
plt.ylabel('Y-Axis', labelpad=20)
plt.show()

# %%
# 질문(고난과 역경)
# 여백의 지정을 할 때 point의 수치에 대해 더 자세히 알고싶다

# %% [markdown]
# ### 폰트 설정하기

# %%
import matplotlib.pyplot as plt

plt.plot([1, 2, 3, 4], [2, 3, 5, 10])
plt.xlabel('X-Axis', labelpad=15, fontdict={'family': 'serif', 'color': 'b', 'weight': 'bold', 'size': 14})
plt.ylabel('Y-Axis', labelpad=20, fontdict={'family': 'fantasy', 'color': 'deeppink', 'weight': 'normal', 'size': 'xx-large'})
# fontdict 파라미터를 사용하면 축 레이블의 폰트 스타일을 설정
plt.show()
# Out:
# WARNING:matplotlib.font_manager:findfont: Generic family 'fantasy' not found because none of the following families were found: Chicago, Charcoal, Impact, Western, xkcd script, fantasy
# WARNING:matplotlib.font_manager:findfont: Generic family 'fantasy' not found because none of the following families were found: Chicago, Charcoal, Impact, Western, xkcd script, fantasy
# WARNING:matplotlib.font_manager:findfont: Generic family 'fantasy' not found because none of the following families were found: Chicago, Charcoal, Impact, Western, xkcd script, fantasy
# WARNING:matplotlib.font_manager:findfont: Generic family 'fantasy' not found because none of the following families were found: Chicago, Charcoal, Impact, Western, xkcd script, fantasy
# WARNING:matplotlib.font_manager:findfont: Generic family 'fantasy' not found because none of the following families were found: Chicago, Charcoal, Impact, Western, xkcd script, fantasy

# %%
import matplotlib.pyplot as plt

font1 = {'family': 'serif',
         'color': 'b',
         'weight': 'bold',
         'size': 14
         }

font2 = {'family': 'fantasy',
         'color': 'deeppink',
         'weight': 'normal',
         'size': 'xx-large'
         } # 폰트의 변수화

plt.plot([1, 2, 3, 4], [2, 3, 5, 10])
plt.xlabel('X-Axis', labelpad=15, fontdict=font1)
plt.ylabel('Y-Axis', labelpad=20, fontdict=font2)
plt.show()
# Out:
# WARNING:matplotlib.font_manager:findfont: Generic family 'fantasy' not found because none of the following families were found: Chicago, Charcoal, Impact, Western, xkcd script, fantasy
# WARNING:matplotlib.font_manager:findfont: Generic family 'fantasy' not found because none of the following families were found: Chicago, Charcoal, Impact, Western, xkcd script, fantasy
# WARNING:matplotlib.font_manager:findfont: Generic family 'fantasy' not found because none of the following families were found: Chicago, Charcoal, Impact, Western, xkcd script, fantasy
# WARNING:matplotlib.font_manager:findfont: Generic family 'fantasy' not found because none of the following families were found: Chicago, Charcoal, Impact, Western, xkcd script, fantasy
# WARNING:matplotlib.font_manager:findfont: Generic family 'fantasy' not found because none of the following families were found: Chicago, Charcoal, Impact, Western, xkcd script, fantasy

# %% [markdown]
# ### 위치 지정하기

# %%
import matplotlib.pyplot as plt

plt.plot([1, 2, 3, 4], [2, 3, 5, 10])
plt.xlabel('X-Axis', loc='right')
# ({‘left’, ‘center’, ‘right’})로 지정 가능
plt.ylabel('Y-Axis', loc='top')
# ({‘bottom’, ‘center’, ‘top’})로 지정 가능
plt.show()

# %% [markdown]
# # 04. Matplotlib 범례 표시하기

# %% [markdown]
# ### 범례 (Legend)는 그래프에 데이터의 종류를 표시하기 위한 텍스트
# ### How? legend() 함수를 사용해서 그래프에 범례를 표시

# %% [markdown]
# ### 기본 사용

# %%
import matplotlib.pyplot as plt

plt.plot([1, 2, 3, 4], [2, 3, 5, 10], label='Price ($)') # plot() 함수에 label 문자열을 지정
plt.xlabel('X-Axis')
plt.ylabel('Y-Axis')
plt.legend() # matplotlib.pyplot 모듈의 legend() 함수를 호출

plt.show()

# %% [markdown]
# ### 위치 지정하기

# %%
import matplotlib.pyplot as plt

plt.plot([1, 2, 3, 4], [2, 3, 5, 10], label='Price ($)')
plt.xlabel('X-Axis')
plt.ylabel('Y-Axis')
plt.legend(loc=(1.0, 1.0))
# legend() 함수의 loc 파라미터를 이용해서 범례가 표시될 위치를 설정 가능

plt.show()

# %%
import matplotlib.pyplot as plt

plt.plot([1, 2, 3, 4], [2, 3, 5, 10], label='Price ($)')
plt.xlabel('X-Axis')
plt.ylabel('Y-Axis')
plt.legend(loc=(0.0, 0.0))

plt.show()

# %%
import matplotlib.pyplot as plt

plt.plot([1, 2, 3, 4], [2, 3, 5, 10], label='Price ($)')
plt.xlabel('X-Axis')
plt.ylabel('Y-Axis')
plt.legend(loc=(0.5, 0.5))

plt.show()

# %%
import matplotlib.pyplot as plt

plt.plot([1, 2, 3, 4], [2, 3, 5, 10], label='Price ($)')
plt.xlabel('X-Axis')
plt.ylabel('Y-Axis')
plt.legend(loc=(1.0, 0.0))

plt.show()

# %%
import matplotlib.pyplot as plt

plt.plot([1, 2, 3, 4], [2, 3, 5, 10], label='Price ($)')
plt.xlabel('X-Axis')
plt.ylabel('Y-Axis')
plt.legend(loc='lower right')

plt.show()

# %% [markdown]
# ### 열 개수 지정하기

# %%
import matplotlib.pyplot as plt

plt.plot([1, 2, 3, 4], [2, 3, 5, 10], label='Price ($)')
plt.plot([1, 2, 3, 4], [3, 5, 9, 7], label='Demand (#)')
plt.xlabel('X-Axis')
plt.ylabel('Y-Axis')
plt.legend(loc='best', ncol=2)

plt.show()

# %%
import matplotlib.pyplot as plt

plt.plot([1, 2, 3, 4], [2, 3, 5, 10], label='Price ($)')
plt.plot([1, 2, 3, 4], [3, 5, 9, 7], label='Demand (#)')
plt.xlabel('X-Axis')
plt.ylabel('Y-Axis')
plt.legend(loc='best', ncol=1)
# ncol = 범례의 '열' 개수

plt.show()

# %% [markdown]
# ### 폰트 크기 지정하기

# %%
import matplotlib.pyplot as plt

plt.plot([1, 2, 3, 4], [2, 3, 5, 10], label='Price ($)')
plt.plot([1, 2, 3, 4], [3, 5, 9, 7], label='Demand (#)')
plt.xlabel('X-Axis')
plt.ylabel('Y-Axis')
plt.legend(loc='best')

plt.show()

# %%
import matplotlib.pyplot as plt

plt.plot([1, 2, 3, 4], [2, 3, 5, 10], label='Price ($)')
plt.plot([1, 2, 3, 4], [3, 5, 9, 7], label='Demand (#)')
plt.xlabel('X-Axis')
plt.ylabel('Y-Axis')
plt.legend(loc='best')
plt.legend(loc='best', ncol=2, fontsize=14)

plt.show()

# %% [markdown]
# ### 범례 테두리 꾸미기

# %%
import matplotlib.pyplot as plt

plt.plot([1, 2, 3, 4], [2, 3, 5, 10], label='Price ($)')
plt.plot([1, 2, 3, 4], [3, 5, 9, 7], label='Demand (#)')
plt.xlabel('X-Axis')
plt.ylabel('Y-Axis')
plt.legend(loc='best', ncol=2, fontsize=14, frameon=True, shadow=True)
# frameon 파라미터는 범례 텍스트 상자의 테두리를 표시할지 여부를 지정
# frameon=False로 지정하면 테두리가 표시되지 않음
# shadow 파라미터를 사용해서 텍스트 상자에 그림자를 표시할 수 있음

plt.show()

# %% [markdown]
# 이 외에도 legend() 함수에는 facecolor, edgecolor, borderpad, labelspacing과 같은 다양한 파라미터가 있습니다.
#
# (고난과 역경)

# %% [markdown]
# # 05. Matplotlib 축 범위 지정하기

# %% [markdown]
# *   xlim() - X축이 표시되는 범위를 지정하거나 반환합니다.
# *   ylim() - Y축이 표시되는 범위를 지정하거나 반환합니다.
# *   axis() - X, Y축이 표시되는 범위를 지정하거나 반환합니다.

# %% [markdown]
# ### 기본 사용 - xlim(), ylim()

# %%
import matplotlib.pyplot as plt

plt.plot([1, 2, 3, 4], [2, 3, 5, 10])
plt.xlabel('X-Axis')
plt.ylabel('Y-Axis')
plt.xlim([0, 5])      # X축의 범위: [xmin, xmax]
plt.ylim([0, 20])     # Y축의 범위: [ymin, ymax]

plt.show()

# %%
# 특별한 입력값 없는 경우

import matplotlib.pyplot as plt

plt.plot([1, 2, 3, 4], [2, 3, 5, 10])
plt.xlabel('X-Axis')
plt.ylabel('Y-Axis')

plt.show()

# %% [markdown]
# ### 기본사용 - axis()

# %%
import matplotlib.pyplot as plt

plt.plot([1, 2, 3, 4], [2, 3, 5, 10])
plt.xlabel('X-Axis')
plt.ylabel('Y-Axis')
plt.axis([0, 5, 0, 20])  # X, Y축의 범위: [xmin, xmax, ymin, ymax]
# axis() 함수에 [xmin, xmax, ymin, ymax]의 형태로 X, Y축의 범위를 지정할 수 있음

plt.show()

# %% [markdown]
# ### 옵션 지정하기

# %% [markdown]
# ### 다양한 옵션이 있음
#
# 'on' | 'off' | 'equal' | 'scaled' | 'tight' | 'auto' | 'normal' | 'image' | 'square'

# %%
import matplotlib.pyplot as plt

plt.plot([1, 2, 3, 4], [2, 3, 5, 10])
plt.xlabel('X-Axis')
plt.ylabel('Y-Axis')
plt.axis('square')
# 축의 길이가 동일하게 표시

plt.show()

# %%
import matplotlib.pyplot as plt

plt.plot([1, 2, 3, 4], [2, 3, 5, 10])
plt.xlabel('X-Axis')
plt.ylabel('Y-Axis')
plt.axis('scaled')
# X, Y축이 같은 길이 스케일로 나타나게 됨

plt.show()

# %% [markdown]
# ### 축 범위 얻기

# %%
import matplotlib.pyplot as plt

plt.plot([1, 2, 3, 4], [2, 3, 5, 10])
plt.xlabel('X-Axis')
plt.ylabel('Y-Axis')

x_range, y_range = plt.xlim(), plt.ylim()
# xlim(), ylim() 함수는 그래프 영역에 표시되는 X축, Y축의 범위를 각각 반환
print(x_range, y_range)

axis_range = plt.axis('scaled')
# axis() 함수는 그래프 영역에 표시되는 X, Y축의 범위를 반환합니다.
print(axis_range)

plt.show()
# X축은 0.85에서 4.15, Y축은 1.6에서 10.4 범위로 표시되었음을 알 수 있음
# Out:
# (np.float64(0.85), np.float64(4.15)) (np.float64(1.6), np.float64(10.4))
# (np.float64(0.85), np.float64(4.15), np.float64(1.6), np.float64(10.4))

# %% [markdown]
# # 06. Matplotlib 선 종류 지정하기

# %% [markdown]
# ### 기본 사용

# %%
import matplotlib.pyplot as plt

plt.plot([1, 2, 3], [4, 4, 4], '-', color='C0', label='Solid')
plt.plot([1, 2, 3], [3, 3, 3], '--', color='C0', label='Dashed')
plt.plot([1, 2, 3], [2, 2, 2], ':', color='C0', label='Dotted')
plt.plot([1, 2, 3], [1, 1, 1], '-.', color='C0', label='Dash-dot')
plt.xlabel('X-Axis')
plt.ylabel('Y-Axis')
plt.axis([0.8, 3.2, 0.5, 5.0])
plt.legend(loc='upper right', ncol=4)
plt.show()

# %% [markdown]
# ### linestyle 지정하기

# %%
import matplotlib.pyplot as plt

plt.plot([1, 2, 3], [4, 4, 4], linestyle='solid', color='C0', label="'solid'")
plt.plot([1, 2, 3], [3, 3, 3], linestyle='dashed', color='C0', label="'dashed'")
plt.plot([1, 2, 3], [2, 2, 2], linestyle='dotted', color='C0', label="'dotted'")
plt.plot([1, 2, 3], [1, 1, 1], linestyle='dashdot', color='C0', label="'dashdot'")
plt.xlabel('X-Axis')
plt.ylabel('Y-Axis')
plt.axis([0.8, 3.2, 0.5, 5.0])
plt.legend(loc='upper right', ncol=4)
plt.tight_layout()
plt.show()

# %% [markdown]
# ### 튜플 사용하기

# %%
import matplotlib.pyplot as plt

plt.plot([1, 2, 3], [4, 4, 4], linestyle=(0, (1, 1)), color='C0', label='(0, (1, 1))')
plt.plot([1, 2, 3], [3, 3, 3], linestyle=(0, (1, 5)), color='C0', label='(0, (1, 5))')
plt.plot([1, 2, 3], [2, 2, 2], linestyle=(0, (5, 1)), color='C0', label='(0, (5, 1))')
plt.plot([1, 2, 3], [1, 1, 1], linestyle=(0, (3, 5, 1, 5)), color='C0', label='(0, (3, 5, 1, 5))')
plt.xlabel('X-Axis')
plt.ylabel('Y-Axis')
plt.axis([0.8, 3.2, 0.5, 5.0])
plt.legend(loc='upper right', ncol=2)
plt.tight_layout()
plt.show()

# %% [markdown]
# ### 선 끝 모양 지정하기

# %%
import matplotlib.pyplot as plt

plt.plot([1, 2, 3], [4, 4, 4], linestyle='solid', linewidth=10,
      solid_capstyle='butt', color='C0', label='solid+butt')
plt.plot([1, 2, 3], [3, 3, 3], linestyle='solid', linewidth=10,
      solid_capstyle='round', color='C0', label='solid+round')

plt.plot([1, 2, 3], [2, 2, 2], linestyle='dashed', linewidth=10,
      dash_capstyle='butt', color='C1', label='dashed+butt')
plt.plot([1, 2, 3], [1, 1, 1], linestyle='dashed', linewidth=10,
      dash_capstyle='round', color='C1', label='dashed+round')

# butt,round로 지정하면 아래 그림과 같이 뭉뚝한, 둥근 끝 모양이 나타남

plt.xlabel('X-Axis')
plt.ylabel('Y-Axis')
plt.axis([0.8, 3.2, 0.5, 5.0])
plt.legend(loc='upper right', ncol=2)
plt.tight_layout()
plt.show()

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# # 07. Matplotlib 마커 지정하기

# %% [markdown]
# ### 기본 사용

# %%
import matplotlib.pyplot as plt

plt.plot([1, 2, 3, 4], [2, 3, 5, 10], 'bo')
plt.xlabel('X-Axis')
plt.ylabel('Y-Axis')
plt.show()

# %% [markdown]
# ### 선/마커 동시에 나타내기

# %%
import matplotlib.pyplot as plt

plt.plot([1, 2, 3, 4], [2, 3, 5, 10], 'bo--')     # 파란색 + 마커 + 점선
plt.xlabel('X-Axis')
plt.ylabel('Y-Axis')
plt.show()

# %%
import matplotlib.pyplot as plt

plt.plot([1, 2, 3, 4], [2, 3, 5, 10], 'bo-')    # 파란색 + 마커 + 실선
plt.xlabel('X-Axis')
plt.ylabel('Y-Axis')
plt.show()

# %% [markdown]
# ### 선/마커 표시 형식

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ### marker 파라미터 사용하기

# %%
import matplotlib.pyplot as plt

plt.plot([4, 5, 6], marker="H") # hexagon
plt.plot([3, 4, 5], marker="d") # thin diamond
plt.plot([2, 3, 4], marker="x") # x
plt.plot([1, 2, 3], marker=11) # carrot downbase
plt.plot([0, 1, 2], marker='$Z$') # $'문자'$ 가져옴
plt.show()

# %% [markdown]
# # 08. Matplotlib 색상 지정하기

# %% [markdown]
# ### 포맷 문자열 사용하기 (f-string)

# %%
import matplotlib.pyplot as plt

plt.plot([1, 2, 3, 4], [2.0, 3.0, 5.0, 10.0], 'r')
plt.plot([1, 2, 3, 4], [2.0, 2.8, 4.3, 6.5], 'g')
plt.plot([1, 2, 3, 4], [2.0, 2.5, 3.3, 4.5], 'b')
plt.xlabel('X-Axis')
plt.ylabel('Y-Axis')

plt.show()

# %% [markdown]
# ### color 키워드 인자 사용하기

# %%
import matplotlib.pyplot as plt

plt.plot([1, 2, 3, 4], [2.0, 3.0, 5.0, 10.0], color='limegreen')
plt.plot([1, 2, 3, 4], [2.0, 2.8, 4.3, 6.5], color='violet')
plt.plot([1, 2, 3, 4], [2.0, 2.5, 3.3, 4.5], color='dodgerblue')
plt.xlabel('X-Axis')
plt.ylabel('Y-Axis')

plt.show()

# %% [markdown]
# ### Hex code 사용하기

# %%
import matplotlib.pyplot as plt

plt.plot([1, 2, 3, 4], [2, 3, 5, 10], color='#e35f62',
         marker='o', linestyle='--') # 16진수 코드 (Hex code)로 더욱 다양한 색상 지정

plt.xlabel('X-Axis')
plt.ylabel('Y-Axis')

plt.show()

# %% [markdown]
# ### Matplotlib 색상들

# %% [markdown]
# ### Cycler 색상
#
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ### 기본 색상
#
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ### Tableau 색상
#
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ### CSS 색상
#
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# # 09. Matplotlib 그래프 영역 채우기

# %% [markdown]
# *   fill_between() - 두 수평 방향의 곡선 사이를 채웁니다.
# *   fill_betweenx() - 두 수직 방향의 곡선 사이를 채웁니다.
# *   fill() - 다각형 영역을 채웁니다.

# %% [markdown]
# ### 기본 사용 - fill_between()

# %%
import matplotlib.pyplot as plt

x = [1, 2, 3, 4]
y = [2, 3, 5, 10]

plt.plot(x, y)
plt.xlabel('X-Axis')
plt.ylabel('Y-Axis')
plt.fill_between(x[1:3], y[1:3], alpha=0.5)
# fill_between() 함수에 x[1:3], y[1:3]를 순서대로 입력하면,
# 네 점 (x[1], y[1]), (x[2], y[2]), (x[1], 0), (x[2], 0)을 잇는 영역이 채워짐
# alpha는 투명도

plt.show()

# %% [markdown]
# ### 기본 사용 - fill_betweenx()

# %%
import matplotlib.pyplot as plt

x = [1, 2, 3, 4]
y = [2, 3, 5, 10]

plt.plot(x, y)
plt.xlabel('X-Axis')
plt.ylabel('Y-Axis')
plt.fill_betweenx(y[2:4], x[2:4], alpha=0.5)

plt.show()

# %%
# 고난과 역경 (헷갈리는데? 어떻게 지정된다는거지?)

# %% [markdown]
# ### 두 그래프 사이 영역 채우기

# %%
import matplotlib.pyplot as plt

x = [1, 2, 3, 4]
y1 = [2, 3, 5, 10]
y2 = [1, 2, 4, 8]

plt.plot(x, y1)
plt.plot(x, y2)
plt.xlabel('X-Axis')
plt.ylabel('Y-Axis')
plt.fill_between(x[1:3], y1[1:3], y2[1:3], color='lightgray', alpha=0.5)

plt.show()

# %% [markdown]
# ### 다각형 영역 채우기 - fill()

# %%
import matplotlib.pyplot as plt

x = [1, 2, 3, 4]
y1 = [2, 3, 5, 10]
y2 = [1, 2, 4, 8]

plt.plot(x, y1)
plt.plot(x, y2)
plt.xlabel('X-Axis')
plt.ylabel('Y-Axis')
plt.fill([1.9, 1.9, 3.1, 3.1], [1.0, 4.0, 6.0, 3.0], color='lightgray', alpha=0.5)

plt.show()

# %%
import matplotlib.pyplot as plt

x = [1, 2, 3, 4]
y1 = [2, 3, 5, 10]
y2 = [1, 2, 4, 8]

plt.plot(x, y1)
plt.plot(x, y2)
plt.xlabel('X-Axis')
plt.ylabel('Y-Axis')
plt.fill([1.9, 1.9, 3.1, 3.1], [1.0, 4.0, 3.0, 6.0], color='lightgray', alpha=0.5)
# 마치 내가 그림을 찍어서 선을 이은 다음에 그 영역이 채워지는 순서구나 (땅따먹기) (고난과 역경)

plt.show()

# %% [markdown]
# # 10. Matplotlib 축 스케일 지정하기

# %% [markdown]
# ### X축 스케일 지정하기

# %%
import matplotlib.pyplot as plt
import numpy as np

x = np.linspace(-10, 10, 100)
y = x ** 3

plt.plot(x, y)
plt.xscale('symlog') # Symmetrical Log Scale
# 축의 원점 기준, 양, 음의 방향이 '대칭적인 로그 스케일'로 표시

plt.show()

# %% [markdown]
# ### Y축 스케일 지정하기

# %%
import matplotlib.pyplot as plt
import numpy as np

x = np.linspace(0, 5, 100)
y = np.exp(x)

plt.plot(x, y)
plt.yscale('log') # 로스 스케일

plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np

x = np.linspace(0, 5, 100)
y = np.exp(x)

plt.plot(x, y)
plt.yscale('linear') # 선형 스케일

plt.show()

# %% [markdown]
# # 11. Matplotlib 여러 곡선 그리기

# %% [markdown]
# ### 기본 사용

# %%
import matplotlib.pyplot as plt
import numpy as np

x = np.arange(0, 2, 0.2) # 어레이 생성

plt.plot(x, x, 'r--', x, x**2, 'bo', x, x**3, 'g-.')
# plot() 함수에 'x 값', 'y 값', '스타일'을 순서대로 세 번씩 입력하면
# 세 개의 곡선 (y=x, y=x^2, y=x^3)이 동시에 그려짐

plt.show()

# %% [markdown]
# ### 스타일 지정하기

# %%
import matplotlib.pyplot as plt
import numpy as np

x = np.arange(0, 2, 0.2)

plt.plot(x, x, 'bo')
plt.plot(x, x**2, color='#e35f62', marker='*', linewidth=2)
plt.plot(x, x**3, color='forestgreen', marker='^', markersize=9)
# linewidth = 선 두께, markersize = 마커의 크기

plt.show()

# %% [markdown]
# # 12. Matplotlib 그리드 설정하기

# %% [markdown]
# ### 기본 사용

# %%
import matplotlib.pyplot as plt
import numpy as np

x = np.arange(0, 2, 0.2)

plt.plot(x, x, 'bo')
plt.plot(x, x**2, color='#e35f62', marker='*', linewidth=2)
plt.plot(x, x**3, color='springgreen', marker='^', markersize=9)
plt.grid(True) # 그리드 생성

plt.show()

# %% [markdown]
# ### 축 지정하기

# %%
import matplotlib.pyplot as plt
import numpy as np

x = np.arange(0, 2, 0.2)

plt.plot(x, x, 'bo')
plt.plot(x, x**2, color='#e35f62', marker='*', linewidth=2)
plt.plot(x, x**3, color='forestgreen', marker='^', markersize=9)
plt.grid(True, axis='y') # axis=y로 설정하면 가로 방향의 그리드만 표시

plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np

x = np.arange(0, 2, 0.2)

plt.plot(x, x, 'bo')
plt.plot(x, x**2, color='#e35f62', marker='*', linewidth=2)
plt.plot(x, x**3, color='forestgreen', marker='^', markersize=9)
plt.grid(True, axis='x')

plt.show()

# %% [markdown]
# ### 스타일 설정하기

# %%
import matplotlib.pyplot as plt
import numpy as np

x = np.arange(0, 2, 0.2)

plt.plot(x, x, 'bo')
plt.plot(x, x**2, color='#e35f62', marker='*', linewidth=2)
plt.plot(x, x**3, color='springgreen', marker='^', markersize=9)
plt.grid(True, axis='y', color='red', alpha=0.5, linestyle='--')

plt.show()

# %% [markdown]
# # 13. Matplotlib 눈금 표시하기

# %% [markdown]
# ### 기본 사용

# %%
import numpy as np

x = np.arange(0, 2, 0.2)

plt.plot(x, x, 'bo')
plt.plot(x, x**2, color='#e35f62', marker='*', linewidth=2)
plt.plot(x, x**3, color='forestgreen', marker='^', markersize=9)
plt.xticks([0, 1, 2])
plt.yticks(np.arange(1, 6))

plt.show()

# %% [markdown]
# ### 눈금 레이블 지정하기

# %%
import matplotlib.pyplot as plt
import numpy as np

x = np.arange(0, 2, 0.2)

plt.plot(x, x, 'bo')
plt.plot(x, x**2, color='#e35f62', marker='*', linewidth=2)
plt.plot(x, x**3, color='springgreen', marker='^', markersize=9)
plt.xticks(np.arange(0, 2, 0.2), labels=['Jan', '', 'Feb', '', 'Mar', '', 'May', '', 'June', '']) # 10개의 레이블로 수정
plt.yticks(np.arange(0, 7), ('0', '1GB', '2GB', '3GB', '4GB', '5GB', '6GB'))

plt.show()

# %% [markdown]
# ### 눈금 스타일 설정하기

# %%
import matplotlib.pyplot as plt
import numpy as np

x = np.arange(0, 2, 0.2)

plt.plot(x, x, 'bo')
plt.plot(x, x**2, color='#e35f62', marker='*', linewidth=2)
plt.plot(x, x**3, color='springgreen', marker='^', markersize=9)
plt.xticks(np.arange(0, 2, 0.2), labels=['Jan', '', 'Feb', '', 'Mar', '', 'May', '', 'June', ''])
plt.yticks(np.arange(0, 7), ('0', '1GB', '2GB', '3GB', '4GB', '5GB', '6GB'))

plt.tick_params(axis='x', direction='in', length=3, pad=6, labelsize=14, labelcolor='green', top=True)
plt.tick_params(axis='y', direction='inout', length=10, pad=15, labelsize=12, width=2, color='r')

# tick_params() 함수 눈금의 스타일을 다양하게 설정 가능

# axis는 설정 가능

# direction을 ‘in’, ‘out’으로 설정하면 눈금이 안/밖으로 표시됩니다. {‘in’, ‘out’, ‘inout’} 중 선택할 수 있습니다.

# length는 눈금의 길이를 지정

# pad는 눈금과 레이블과의 거리를 지정

# labelsize는 레이블의 크기를 지정

# labelcolor는 레이블의 색상을 지정

# top/bottom/left/right를 True/False로 지정하면 눈금이 표시될 위치를 선택

# width는 눈금의 너비를 지정

# color는 눈금의 색상을 지정

plt.show()

# %% [markdown]
# # 14. Matplotlib 타이틀 설정하기

# %% [markdown]
# ### 기본 사용

# %%
import matplotlib.pyplot as plt
import numpy as np

x = np.arange(0, 2, 0.2)

plt.plot(x, x, 'bo')
plt.plot(x, x**2, color='#e35f62', marker='*', linewidth=2)
plt.plot(x, x**3, color='forestgreen', marker='^', markersize=9)

plt.tick_params(axis='both', direction='in', length=3, pad=6, labelsize=14)
plt.title('Graph Title') # title() 함수를 이용해서 그래프의 타이틀 지정

plt.show()

# %% [markdown]
# ### 위치와 오프셋 지정하기

# %%
import matplotlib.pyplot as plt
import numpy as np

x = np.arange(0, 2, 0.2)

plt.plot(x, x, 'bo')
plt.plot(x, x**2, color='#e35f62', marker='*', linewidth=2)
plt.plot(x, x**3, color='forestgreen', marker='^', markersize=9)

plt.tick_params(axis='both', direction='in', length=3, pad=6, labelsize=14)
plt.title('Graph Title', loc='right', pad=20)
# plt.title() 함수의 loc 파라미터로 위치 설정 가능
# {‘left’, ‘center’, ‘right’} 중 선택할 수 있으며 디폴트는 ‘center'
# pad 파라미터는 타이틀과 그래프와의 간격을 포인트 단위로 설정

plt.show()

# %% [markdown]
# ### 폰트 지정하기

# %%
import matplotlib.pyplot as plt
import numpy as np

x = np.arange(0, 2, 0.2)

plt.plot(x, x, 'bo')
plt.plot(x, x**2, color='#e35f62', marker='*', linewidth=2)
plt.plot(x, x**3, color='forestgreen', marker='^', markersize=9)

plt.tick_params(axis='both', direction='in', length=3, pad=6, labelsize=14)
plt.title('Graph Title', loc='right', pad=20)

title_font = {
    'fontsize': 16,
    'fontweight': 'bold'
}
plt.title('Graph Title', fontdict=title_font, loc='left', pad=20)

# fontdict 파라미터에 딕셔너리 형태로 폰트 스타일을 설정 가능
#‘fontsize’는 포인트 단위의 숫자를 입력하거나
#‘smaller’, ‘x-large’ 등의 상대적인 설정 가능
#‘fontweight’에는 {‘normal’, ‘bold’, ‘heavy’, ‘light’}와 같이 설정

plt.show()

# %% [markdown]
# ### 타이틀 얻기

# %%
import matplotlib.pyplot as plt
import numpy as np

x = np.arange(0, 2, 0.2)

plt.plot(x, x, 'bo')
plt.plot(x, x**2, color='#e35f62', marker='*', linewidth=2)
plt.plot(x, x**3, color='forestgreen', marker='^', markersize=9)

plt.tick_params(axis='both', direction='in', length=3, pad=6, labelsize=14)
title_right = plt.title('Graph Title', loc='right', pad=20)

title_font = {
    'fontsize': 16,
    'fontweight': 'bold'
}
title_left = plt.title('Graph Title', fontdict=title_font, loc='left', pad=20)

print(title_left.get_position())
print(title_left.get_text())

print(title_right.get_position())
print(title_right.get_text())

# plt.title() 함수는 타이틀을 나타내는 Matplotlib text 객체를 반환
# get_position()과 get_text() 메서드를 사용해서 텍스트 위치와 문자열을 얻을 수 있다

plt.show()
# Out:
# (0.0, 1.0)
# Graph Title
# (1.0, 1.0)
# Graph Title

# %% [markdown]
# # 15. Matplotlib 수평선/수직선 표시하기

# %% [markdown]
# * axhline(): 축을 따라 수평선을 표시합니다.
# * axvline(): 축을 따라 수직선을 표시합니다.
# * hlines(): 지정한 점을 따라 수평선을 표시합니다.
# * vlines(): 지정한 점을 따라 수직선을 표시합니다.

# %% [markdown]
# ### 수평선 그리기 - axhline(), hlines()

# %%
import matplotlib.pyplot as plt

x = np.arange(0, 4, 0.5)

plt.plot(x, x + 1, 'bo')
plt.plot(x, x**2 - 4, 'g--')
plt.plot(x, -2*x + 3, 'r:')

plt.axhline(4.0, 0.1, 0.9, color='lightgray', linestyle='--', linewidth=2)
plt.hlines(-0.62, 1.0, 2.5, color='gray', linestyle='solid', linewidth=3)

# axhline() 함수의 첫번째 인자는 y 값으로서 수평선의 위치가 됨
# 두, 세번째 인자는 xmin, xmax 값으로서 0에서 1 사이의 값을 입력합니다.
# 0은 왼쪽 끝, 1은 오른쪽 끝을 의미합니다.

# hlines() 함수에 y, xmin, xmax를 순서대로 입력하면,
# 점 (xmin, y)에서 점 (xmax, y)를 따라 수평선을 표시합니다.
# 결과는 아래와 같습니다.

plt.show()

# %% [markdown]
# ### 수직선 그리기 - axvline(), vlines()

# %%
import matplotlib.pyplot as plt

x = np.arange(0, 4, 0.5)

plt.plot(x, x + 1, 'bo')
plt.plot(x, x**2 - 4, 'g--')
plt.plot(x, -2*x + 3, 'r:')

plt.axvline(1.0, 0.2, 0.8, color='lightgray', linestyle='--', linewidth=2)
plt.vlines(1.8, -3.0, 2.0, color='gray', linestyle='solid', linewidth=3)

plt.show()

# %% [markdown]
# # 16. Matplotlib 막대 그래프 그리기

# %% [markdown]
# ### 기본 사용

# %%
import matplotlib.pyplot as plt
import numpy as np

x = np.arange(3)
years = ['2018', '2019', '2020']
values = [100, 400, 900]

plt.bar(x, values)
plt.xticks(x, years)

# plt.bar() 함수에 x 값 [0, 1, 2]와 y 값 [100, 400, 900]를 입력해주고,
# xticks()에 x와 years를 입력해주면,
# X축의 눈금 레이블에 ‘2018’, ‘2019’, ‘2020’이 순서대로 표시됩니다.

plt.show()

# %% [markdown]
# ### 색상 지정하기

# %%
import matplotlib.pyplot as plt
import numpy as np

x = np.arange(3)
years = ['2018', '2019', '2020']
values = [100, 400, 900]

plt.bar(x, values, color='y')
# plt.bar(x, values, color='dodgerblue')
# plt.bar(x, values, color='C2')
# plt.bar(x, values, color='#e35f62')
plt.xticks(x, years)

plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np

x = np.arange(3)
years = ['2018', '2019', '2020']
values = [100, 400, 900]
colors = ['y', 'dodgerblue', 'C2']

plt.bar(x, values, color=colors)
plt.xticks(x, years)

plt.show()

# %% [markdown]
# ### 막대 폭 지정하기

# %%
import matplotlib.pyplot as plt
import numpy as np

x = np.arange(3)
years = ['2018', '2019', '2020']
values = [100, 400, 900]

plt.bar(x, values, width=0.4)
plt.xticks(x, years)

plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np

x = np.arange(3)
years = ['2018', '2019', '2020']
values = [100, 400, 900]

plt.bar(x, values, width=0.6)
plt.xticks(x, years)

plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np

x = np.arange(3)
years = ['2018', '2019', '2020']
values = [100, 400, 900]

plt.bar(x, values, width=0.8) # 이게 디폴
plt.xticks(x, years)

plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np

x = np.arange(3)
years = ['2018', '2019', '2020']
values = [100, 400, 900]

plt.bar(x, values, width=1.0)
plt.xticks(x, years)

plt.show()

# %% [markdown]
# ### 스타일 꾸미기

# %%
import matplotlib.pyplot as plt
import numpy as np

x = np.arange(3)
years = ['2018', '2019', '2020']
values = [100, 400, 900]

plt.bar(x, values, align='edge', edgecolor='lightgray',
        linewidth=5, tick_label=years)

# align은 눈금과 막대의 위치를 조절 (디폴트 값은 ‘center’)
#‘edge’로 설정하면 막대의 왼쪽 끝에 눈금이 표시
# edgecolor는 막대 테두리 색, linewidth는 테두리의 두께를 지정합니다.
# tick_label을 리스트 또는 어레이 형태로 지정하면,
# 틱에 문자열을 순서대로 나타낼 수 있습니다.

plt.show()

# %% [markdown]
# # 17. Matplotlib 수평 막대 그래프 그리기

# %% [markdown]
# ### 기본 사용

# %%
import matplotlib.pyplot as plt
import numpy as np

y = np.arange(3)
years = ['2018', '2019', '2020']
values = [100, 400, 900]

plt.barh(y, values)
plt.yticks(y, years)

# years는 Y축에 표시될 연도이고, values는 막대 그래프의 너비로 표시될 x 값 입니다.

# 먼저 barh() 함수에 NumPy 어레이 [0, 1, 2]와 x 값에 해당하는 리스트 [100, 400, 900]를 입력해줍니다.

# 다음, yticks()에 y와 years를 입력해주면, Y축의 눈금 레이블에 ‘2018’, ‘2019’, ‘2020’이 순서대로 표시됩니다.

plt.show()

# %% [markdown]
# ### 색상 지정하기

# %%
import matplotlib.pyplot as plt
import numpy as np

y = np.arange(3)
years = ['2018', '2019', '2020']
values = [100, 400, 900]

plt.barh(y, values, color='y')
# plt.barh(y, values, color='dodgerblue')
# plt.barh(y, values, color='C2')
# plt.barh(y, values, color='#e35f62')
plt.yticks(y, years)

plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np

y = np.arange(3)
years = ['2018', '2019', '2020']
values = [100, 400, 900]
colors = ['y', 'dodgerblue', 'C2']

plt.barh(y, values, color=colors)
plt.yticks(y, years)

plt.show()

# %% [markdown]
# ### 막대 높이 지정하기

# %%
import matplotlib.pyplot as plt
import numpy as np

y = np.arange(3)
years = ['2018', '2019', '2020']
values = [100, 400, 900]

plt.barh(y, values, height=0.4) # 앞서 나온 두께 같은 거
plt.yticks(y, years)

plt.show()

# %% [markdown]
# ### 스타일 꾸미기

# %%
import matplotlib.pyplot as plt
import numpy as np

y = np.arange(3)
years = ['2018', '2019', '2020']
values = [100, 400, 900]

plt.barh(y, values, align='edge', edgecolor='#eee',
         linewidth=5, tick_label=years)

plt.show()
