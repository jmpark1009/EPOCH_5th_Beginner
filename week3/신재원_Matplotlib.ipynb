# %% [markdown]
# **01**.Matplotlib 기본 사용

# %%
#예제1
import matplotlib.pyplot as plt
plt.plot([1, 2, 3, 4]) #y값 지정
plt.show()

# %%
#예제2
import matplotlib.pyplot as plt
plt.plot([1, 2, 3, 4], [1, 4, 9, 16]) #x-y값

# %% [markdown]
# 스타일 지정하기

# %%
import matplotlib.pyplot as plt

plt.plot([1, 2, 3, 4], [1, 4, 9, 16], 'ro') #빨간색의(r) 원형마커(o)
plt.axis([0, 6, 0, 20]) #축의 범위 : [xmin, xmax, ymin, yma]
plt.show()

# %% [markdown]
# 여러 개의 그래프 그리기

# %%
import matplotlib.pyplot as plt
import numpy as np
#200ms 간격으로 균일하게 샘플된 시간
t = np.arange(0., 5., 0.2) #범위 0부터 5까지

#빨간 대쉬, 파란사각형, 녹색 삼각형
plt.plot(t, t, 'r--', t, t**2, 'bs', t, t**3, 'g^')
plt.show()

# %% [markdown]
# 2.Matplotlib 숫자 입력하기

# %%
import matplotlib.pyplot as plt
plt.plot([2, 3, 5, 10]) #y값으로 인식, x값: [0, 1,1,2,3]
plt.show()

# %%
#x,y값 입력
import matplotlib.pyplot as plt
plt.plot([1, 2, 3, 4], [2, 3, 5, 10]) #순서대로 x,y값으로 인식
plt.show()

# %% [markdown]
# 03.축레이블 지정하기

# %%
#레이블이 있는 데이터 사용
import matplotlib.pyplot as plt
plt.plot([1,2,3,4], [2,3,5,10])
data_dict = {'data_x': [1, 2, 3, 4, 5], 'data_y': [2, 3, 5, 10, 8]}

plt.plot('data_x', 'data_y', data=data_dict ) #plot() 함수에 레이블 입력후 딕셔너리 지정
plt.show()

# %%
#Matplotlib 축레이블 설정
plt.xlabel('X-Axis', labelpad=15, fontdict= {'family': 'serif',
'color': 'b', 'weight': 'bold', 'size':14})
plt.ylabel('Y-Axis', labelpad=20, fontdict={'family': 'fanctasy', 'color': 'deeppink', 'weight': 'normal', 'size': 'xx-large'})
plt.show()
# Out:
# WARNING:matplotlib.font_manager:findfont: Font family 'fanctasy' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'fanctasy' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'fanctasy' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'fanctasy' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'fanctasy' not found.

# %% [markdown]
# 위치 지정하기

# %%
import matplotlib.pyplot as plt
plt.plot([1,2,3,4], [2,3,5,10])
plt.xlabel('X-Axis', loc = 'right') #x축 레이블 위치 지정: ({'left', 'center', ;right'})
plt.ylabel('Y-Axis', loc='top') #y축 레이블 위치 지정: ({'bottom', ''center', 'top'})
plt.show()

# %% [markdown]
# 04.Matplotlib 범례 표시

# %% [markdown]
# 범례: 그래프 데이터 종류 표시하기 위한 텍스트

# %%
import matplotlib.pyplot as plt

plt.plot([1, 2, 3, 4], [2, 3, 5, 10], label = 'Price($)')
plt.xlabel('X-Axis')
plt.ylabel('Y-Axis')
plt.legend()

plt.show()

# %% [markdown]
# 위치 지정하기

# %%
#예제1
import matplotlib.pyplot as plt

plt.plot([1, 2, 3, 4], [2, 3, 5, 10], label = 'Price($)')
plt.xlabel('X-Axis')
plt.ylabel('Y-Axis')
plt.legend(loc=(0.0, 0.0)) #범례가 표시될 위치 표시
#loc=(0.0, 0.0) 데이터 영역 왼쪽 아래
#loc=(1.0, 1.0) 데이터 영역 오른쪽 위
plt.legend(loc=(1.0,1.0))

plt.show()

# %%
#예제2
import matplotlib.pyplot as plt

plt.plot([1, 2, 3, 4], [2, 3, 5, 10], label='Price($)')
plt.xlabel('X-Axis')
plt.ylabel('Y-Axis')
plt.legend(loc='lower right') #오른쪽 아래 범례
plt.show()

# %% [markdown]
# 열 개수 지정하기

# %%
import matplotlib.pyplot as plt

plt.plot([1, 2, 3, 4], [2, 3, 5, 10], label='Price ($)')
plt.plot([1, 2, 3, 4], [3, 5, 9, 7], label='Demand (#)')
plt.xlabel('X-Axis')
plt.ylabel('Y-Axis')
#plt.legend(loc='best')           #ncol = 1
plt.legend(loc='best', ncol=2)    #ncol = 2

plt.show()

# %% [markdown]
# 범례 테두리 꾸미기

# %%
import matplotlib.pyplot as plt

plt.plot([1, 2, 3, 4], [2, 3, 5, 10], label = 'Price ($)')
plt.plot([1, 2, 3, 4], [3, 5, 9, 7], label='Demand (#)')

plt.xlabel('X-Axis')
plt.ylabel('Y-Axis')

plt.legend(loc='best', ncol=2, fontsize=14, frameon=True, shadow=True) #frameon:범례 테스트 상자의 테두리 표시 여부

plt.show()

# %% [markdown]
# **5. Matplottib 축 범위 지정하기**

# %% [markdown]
# *  xlim()- X축이 표시되는 범위 지정/반환
# *  ylim()- Y축이 표시되는 범위 지정/반환
#
#
# * axis()- X,Y 축이 표시되는 범위 지정/반환

# %%
#plt.xlim(xmin, xmax)
#plt.xlim((xmin, xmax))
#plt.xlim([xmin, xmax])
import matplotlib.pyplot as plt

plt.plot([1, 2, 3, 4], [2, 3, 5, 20])
plt.xlabel('X-Axis')
plt.ylabel('Y-Axis')
plt.xlim([0, 5])  #X축의 범위: [xmin, xmax]
plt.ylim([0, 20]) #Y축의 범위: [ymin, ymax]

plt.show()

# %% [markdown]
# **기본사용-axis()**

# %%
import matplotlib.pyplot as plt

plt.plot([1, 2, 3, 4], [2, 3, 5, 10])
plt.xlabel('X-Axis')
plt.ylabel('Y-Axis')
plt.axis([0, 5, 0, 20]) #X, Y축의 범위: [xmin, xmax, ymin, ymax]

plt.show()

# %% [markdown]
# 옵션 지정하기

# %% [markdown]
# plt.axis('square')
#
#
# ---
#
#
# plt.axis('scaled')

# %%
import matplotlib.pyplot as plt

plt.plot([1, 2, 3, 4], [2, 3, 5, 10])
plt.xlabel('X-Axis')
plt.ylabel('Y-Axis')
#plt.axis('square')
plt.axis('scaled')

plt.show()

# %% [markdown]
# 축 범위 얻기

# %%
import matplotlib.pyplot as plt

plt.plot([1, 2, 3, 4], [2, 3, 5, 10])
plt.xlabel('X-Axis')
plt.ylabel('Y-Axis')

x_range, y_range = plt.xlim(), plt.ylim()
print(x_range, y_range)

axis_range = plt.axis('scaled')
print(axis_range)

plt.show()
# Out:
# (np.float64(0.85), np.float64(4.15)) (np.float64(1.6), np.float64(10.4))
# (np.float64(0.85), np.float64(4.15), np.float64(1.6), np.float64(10.4))

# %% [markdown]
# 6.Matplotlib 선 종류 지정하기

# %%
import matplotlib.pyplot as plt

plt.plot([1, 2, 3], [4, 4, 4], '-', color='C0', label='Solid')
plt.plot([1, 2, 3], [3, 3, 3], '--', color='C0', label='Dashed')
plt.plot([1, 2, 3], [2, 2, 2], ':', color='C0', label='Dotted')
plt.plot([1, 2, 3], [1, 1, 1], '-.', color='C0', label='Dash-dot')
plt.xlabel('X-Axis')
plt.ylabel('Y-Axis')
plt.axis([0.8, 3.2, 0.5, 5.0])
plt.legend(loc='upper right', ncol=4)
plt.show()

# %% [markdown]
# linestyle 지정하기

# %%
#plt.plot(x, y, linestlye='solid')

#plt.plot(x, y, linestyle='dashed')

#plt.plot(x, y, linestyle='dotted')

#plt.plot(x, y, linestyle='dashdot')

# %%
import matplotlib.pyplot as plt

plt.plot([1, 2, 3], [4, 4, 4], linestyle='solid', color='C0', label="'solid'")
plt.plot([1, 2, 3], [3, 3, 3], linestyle='dashed', color='C0', label="'dashed'")
plt.plot([1, 2, 3], [2, 2, 2], linestyle='dotted', color='C0', label="'dotted'")
plt.plot([1, 2, 3], [1, 1, 1], linestyle='dashdot', color='C0', label="'dashdot'")
plt.xlabel('X-Axis')
plt.ylabel('Y-Axis')
plt.axis([0.8, 3.2, 0.5, 5.0])
plt.legend(loc='upper right', ncol=4)
plt.tight_layout()
plt.show()

# %% [markdown]
# 튜플 사용하기

# %%
#plt.plot(x, y, linestyle=(0, (1, 1))) : Solid
#plt.plot(x, y, linestyle=(0, (1, 5))) :Dashed
#plt.plot(x, y, linestyle=(0, (5, 1))) : Dotted
#plt.plot(x, y, linestyle=(0, (3, 5, 1, 5))) : Dash-dot

# %%
import matplotlib.pyplot as plt

plt.plot([1, 2, 3], [4, 4, 4], linestyle=(0, (1, 1)), color='C0', label='(0, (1, 1))') #dotted
plt.plot([1, 2, 3], [3, 3, 3], linestyle=(0, (1, 5)), color='C0', label='(0, (1, 5))') #dashed
plt.plot([1, 2, 3], [2, 2, 2], linestyle=(0, (5, 1)), color='C0', label='(0, (5, 1))') #dotted
plt.plot([1, 2, 3], [1, 1, 1], linestyle=(0, (3, 5, 1, 5)), color='C0', label='(0, (3, 5, 1, 5))') #Dash-dot
plt.xlabel('X-Axis')
plt.ylabel('Y-Axis')
plt.axis([0.8, 3.2, 0.5, 5.0])
plt.legend(loc='upper right', ncol=2)
plt.tight_layout()
plt.show()

# %% [markdown]
# 선 끝 모양 지정하기

# %%
import matplotlib.pyplot as plt

plt.plot([1, 2, 3], [4, 4, 4], linestyle='solid', linewidth=10, solid_capstyle='butt', color='C0', label='solid+butt')
plt.plot([1, 2, 3], [3, 3, 3], linestyle='solid', linewidth=10, solid_capstyle='round', color='C0', label='solid+round')

plt.plot([1, 2, 3], [2, 2, 2], linestyle='dashed', linewidth=10, dash_capstyle='butt', color='C1', label='dashed+butt')
plt.plot([1, 2, 3], [1, 1, 1], linestyle='dashed', linewidth=10, dash_capstyle='round', color='C1', label='dashed+round')

plt.xlabel('X-Axis')
plt.ylabel('Y-Axis')
plt.axis([0.8, 3.2, 0.5, 5.0])
plt.legend(loc='upper right', ncol=2)
plt.tight_layout()
plt.show()

# %% [markdown]
# 7.Matplotlib 마커 지정하기

# %%
import matplotlib.pyplot as plt

plt.plot([1, 2, 3, 4], [2, 3, 5, 10], 'bo')
plt.xlabel('X-Axis')
plt.ylabel('Y-Axis')
plt.show()

# %% [markdown]
# 선/마커 동시에 나타내기

# %%
import matplotlib.pyplot as plt

#plt.plot([1, 2, 3, 4], [2, 3, 5, 10], 'bo-') #파란색+마커+실선
plt.plot([1, 2, 3, 4], [2, 3, 5, 10], 'bo--') #파란색+마커+점선
plt.xlabel('X-Axis')
plt.ylabel('Y-Axis')
plt.show()

# %% [markdown]
# *   'b' #blue markers with default shape
# *   'ro' #red circles
#
# *   'g-' #green solid line
#
# *   '--' #dashed line with default color
#
# *   'k^:' #black triangle_up markers connected by a dotted line

# %% [markdown]
# colors, Line Styles, Markers 다 정리되어있음

# %% [markdown]
# marker 파라미터 사용하기

# %%
import matplotlib.pyplot as plt

plt.plot([4, 5, 6], marker="H") #hexagon2
plt.plot([3, 4, 5], marker="d") #thin_diamond
plt.plot([2, 3, 4], marker="x") #x
plt.plot([1, 2, 3], marker=11) #아래 화살표
plt.plot([0, 1, 2], marker='$Z$') #$()$: () 모양
plt.show()

# %% [markdown]
# 8. Matplotlib 색상 지정하기

# %% [markdown]
# 포맷 문자열 사용

# %%
import matplotlib.pyplot as plt

plt.plot([1, 2, 3, 4], [2.0, 3.0, 5.0, 10.0], 'r')
plt.plot([1, 2, 3, 4], [2.0, 2.8, 4.3, 6.5], 'g')
plt.plot([1, 2, 3, 4], [2.0, 2.5, 3.3, 4.5], 'b') #포맷 문자열 사용해서 실선 색상 지
plt.xlabel('X-Axis')
plt.ylabel('Y-Axis')

plt.show()

# %% [markdown]
# color 키워드 인자 사용하기

# %%
import matplotlib.pyplot as plt

plt.plot([1, 2, 3, 4], [2.0, 3.0, 5.0, 10.0], color='limegreen')
plt.plot([1, 2, 3, 4], [2.0, 2.8, 4.3, 6.5], color='violet')
plt.plot([1, 2, 3, 4], [2.0, 2.5, 3.3, 4.5], color='dodgerblue')
plt.xlabel('X-Axis')
plt.ylabel('Y-Axis')

plt.show()

# %% [markdown]
# Hex code 사용하기

# %%
import matplotlib.pyplot as plt

plt.plot([1, 2, 3, 4], [2, 3, 5, 10], color='#e35f62', marker='o', linestyle='--')
plt.xlabel('X-Axis')
plt.ylabel('Y-Axis')

plt.show()

# %% [markdown]
# 9.Matplotlib 그래프 영역 채우기

# %% [markdown]
# * fill_between(): 두 수평 방향의 곡선 사이 채움
#
# * fill_betweenx(): 두 수직 방향의 곡선 사이를 채움
#
# * fill() : 다각형 영역 채움

# %%
#fill_between()
import matplotlib.pyplot as plt

x = [1, 2, 3, 4]
y = [2, 3, 5, 10]

plt.plot(x, y)
plt.xlabel('X-Axis')
plt.ylabel('Y-Axis')
plt.fill_between(x[1:3], y[1:3], alpha=0.7) #alpha : 불투명도

plt.show()

# %%
#fill_betweenx()
import matplotlib.pyplot as plt

x = [1, 2, 3, 4]
y = [2, 3, 5, 10]

plt.plot(x, y)
plt.xlabel('X-Axis')
plt.ylabel('Y-Axis')
plt.fill_betweenx(y[2:4], x[2:4], alpha=0.5) #네 점 (x[2], y[2]), (x[3], y[3]), (0, y[2]), (0, y[3])을 잇는 영역이 채워짐

plt.show()

# %%
#두 그래프 사이 영역 채우기
import matplotlib.pyplot as plt

x = [1, 2, 3, 4]
y1 = [2, 3, 5, 10]
y2 = [1, 2, 4, 8]

plt.plot(x, y1)
plt.plot(x, y2)
plt.xlabel('X-Axis')
plt.ylabel('Y-Axis')
plt.fill_between(x[1:3], y1[1:3], y2[1:3], color='lightgray', alpha=0.5)

plt.show()

# %% [markdown]
# 다각형 영역 채우기-fill()

# %%
import matplotlib.pyplot as plt

x = [1, 2, 3, 4]
y1 = [2, 3, 5, 10]
y2 = [1, 2, 4, 8]

plt.plot(x, y1)
plt.plot(x, y2)
plt.xlabel('X-Axis')
plt.ylabel('Y-Axis')
plt.fill([1.9, 1.9, 3.1, 3.1], [1.0, 4.0, 6.0, 3.0], color='lightgray', alpha=0.5)

plt.show()

# %% [markdown]
# 10.Matplotlib 축 스케일 지정하기

# %% [markdown]
# X축 스케일 지정하기

# %%
import matplotlib.pyplot as plt
import numpy as np

x = np.linspace(-10, 10, 100)
y = x ** 3

plt.plot(x, y)
plt.xscale('symlog') #x축 스케일 지정: Symmetrical Log Scale

plt.show()

# %% [markdown]
# Y축 스케일 지정하기

# %%
import matplotlib.pyplot as plt
import numpy as np

x = np.linspace(0, 5, 100)
y = np.exp(x) #지수함수(Exponential function)와 같이 기하급수적 변화하는 데이터 표현

plt.plot(x, y)
plt.yscale('linear') #지수함수 형태
#plt.yscale('log') #직선형태

plt.show()

# %% [markdown]
# 11.Matplotlib 여러 곡선 그리기

# %% [markdown]
# 기본 사용
#
#
# ---
# plt.plot(x, y1, 'r--', x, y2, 'bo', x, y3, 'g-.')

# %%
import matplotlib.pyplot as plt
import numpy as np

x = np.arange(0, 2, 0.2)

plt.plot(x, x, 'r--', x, x**2, 'bo', x, x**3, 'g-.')
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np

x = np.arange(0, 2, 0.2)

plt.plot(x, x, 'bo')
plt.plot(x, x**2, color='#e35f62', marker='*', linewidth=2)
plt.plot(x, x**3, color='forestgreen', marker='^', markersize=9)
plt.show()

# %% [markdown]
# 12. Matplotlib 그리드 설정하기

# %%
import matplotlib.pyplot as plt
import numpy as np

x = np.arange(0, 2, 0.2)

plt.plot(x, x, 'bo')
plt.plot(x, x**2, color='#e35f62', marker='*', linewidth=2)
plt.plot(x, x**3, color='springgreen', marker='^', markersize=9)
plt.grid(True) #그래프의 x,y축에 대한 그리드 표시

plt.show()

# %% [markdown]
# 축 지정하기

# %%
#plt.grid(True, axis='x') X축에 대해 수직인 직선
#plt.grid(True, axis='y') Y축에 대해 수직인 직선

# %%
import matplotlib.pyplot as plt
import numpy as np

x = np.arange(0, 2, 0.2)

plt.plot(x, x, 'bo')
plt.plot(x, x**2, color='#e35f62', marker='*', linewidth=2)
plt.plot(x, x**3, color='forestgreen', marker='^', markersize=9)
plt.grid(True, axis='y') #가로방향 그리드만 표시/ both가 디폴

plt.show()

# %%
from matplotlib import lines
import matplotlib.pyplot as plt
import numpy as np

x = np.arange(0, 2, 0.2)

plt.plot(x, x, 'bo')
plt.plot(x, x**2, color='#e35f62', marker='*', linewidth=2)
plt.plot(x, x**3, color='springgreen', marker='^', markersize=9)
plt.grid(True, axis='y', color='red', alpha=0.5, linestyle='--')

plt.show()

# %% [markdown]
# 13.Matplotlib 눈금 표시하기

# %% [markdown]
# 틱(Tick) : 축에 간격 구분하기 위해 표시하는 눈금

# %%
import numpy as np

x = np.arange(0, 2, 0.2)

plt.plot(x, x, 'bo')
plt.plot(x, x**2, color='#e35f62', marker='*', linewidth=2)
plt.plot(x, x**3, color='forestgreen', marker='^', markersize=9)
plt.xticks([0, 1, 2])
plt.yticks(np.arange(1, 6))

plt.show()

# %% [markdown]
# 눈금 레이블 지정하기

# %%
#plt.xticks([0, 1, 2], label=['Jan', 'Feb', 'Mar'])
#plt.yticks([1, 2, 3, 4], labe=['A', 'B', 'C', 'D'])

# %%
import matplotlib.pyplot as plt
import numpy as np

x = np.arange(0, 2, 0.2)

plt.plot(x, x, 'bo')
plt.plot(x, x**2, color='#e35f62', marker='*', linewidth=2)
plt.plot(x, x**3, color='springgreen', marker='^', markersize=9)
plt.xticks(np.arange(0, 2, 0.2), labels=['Jan', '', 'Feb', '', 'Mar', '', 'May', '', 'June', '', 'July'])
plt.yticks(np.arange(0, 7), ('0', '1GB', '2GB', '3GB', '4GB', '5GB', '6GB'))

plt.show()

# %% [markdown]
# 눈금 스타일 설정하기

# %% [markdown]
# plt.tick_params(axis='x', direction='in',..)
#
#
# ---
#
# plt.tick_params(axis='y', direction='out',...)

# %%
import matplotlib.pyplot as plt
import numpy as np

x = np.arange(0, 2, 0.2)

plt.plot(x, x, 'bo')
plt.plot(x, x**2, color='#e35f62', marker='*', linewidth=2)
plt.plot(x, x**3, color='springgreen', marker='^', markersize=9)
plt.xticks(np.arange(0, 2, 0.2), labels=['Jan', '', 'Feb', '', 'Mar', '', 'May', '', 'June', ''])
plt.yticks(np.arange(0, 7), ('0', '1GB', '2GB', '3GB', '4GB', '5GB', '6GB'))

plt.tick_params(axis='x', direction='in', length=3, pad=6, labelsize=14, labelcolor='green', top=True)
plt.tick_params(axis='y', direction='inout', length=10, pad=15, labelsize=12, width=2, color='r')

plt.show()

# %% [markdown]
# 14.Matplotlib 타이틀 설정

# %% [markdown]
# plt.title('Graph Title')

# %%
import matplotlib.pyplot as plt
import numpy as np

x = np.arange(0, 2, 0.2)

plt.plot(x, x, 'bo')
plt.plot(x, x**2, color='#e35f62', marker='*', linewidth=2)
plt.plot(x, x**3, color='forestgreen', marker='^', markersize=9)

plt.tick_params(axis='both', direction='in', length=3, pad=6, labelsize=14)
plt.title('Graph Title') #그래프 타이틀 설

plt.show()

# %% [markdown]
# 위치와 오프셋 지정하기

# %% [markdown]
# plt.title('Graph Title', loc='right', pad=20)

# %%
import matplotlib.pyplot as plt
import numpy as np

x = np.arange(0, 2, 0.2)

plt.plot(x, x, 'bo')
plt.plot(x, x**2, color='#e35f62', marker='*', linewidth=2)
plt.plot(x, x**3, color='forestgreen', marker='^', markersize=9)

plt.tick_params(axis='both', direction='in', length=3, pad=6, labelsize=14)
plt.title('Graph Title', loc='right', pad=20) #loc:right로 설정하면 타이틀 그래프의 오른쪽 위에 나타나게

plt.show()

# %% [markdown]
# 폰트 지정하기

# %% [markdown]
# plt.title('Graph Title', fontdict={...})

# %%
import matplotlib.pyplot as plt
import numpy as np

x = np.arange(0, 2, 0.2)

plt.plot(x, x, 'bo')
plt.plot(x, x**2, color='#e35f62', marker='*', linewidth=2)
plt.plot(x, x**3, color='forestgreen', marker='^', markersize=9)

plt.tick_params(axis='both', direction='in', length=3, pad=6, labelsize=14)
plt.title('Graph Title', loc='right', pad=20)

title_font = {
    'fontsize': 16,
    'fontweight':'bold'} #‘fontsize’를 16으로, ‘fontweight’를 ‘bold’로 설정

#‘fontsize’는 포인트 단위의 숫자를 입력하거나 ‘smaller’, ‘x-large’ 등의 상대적인 설정.

#‘fontweight’에는 {‘normal’, ‘bold’, ‘heavy’, ‘light’, ‘ultrabold’, ‘ultralight’}와 같이 설정할 수 있습니다.
plt.title('Graph Title', fontdict=title_font, loc='left', pad=20)

plt.show()

# %% [markdown]
# 타이틀 얻기

# %% [markdown]
# title_pos = title.get_postition()
#
#
# ---
#
#
# title_str = title.get_text()

# %%
import matplotlib.pyplot as plt
import numpy as np

x = np.arange(0, 2, 0.2)

plt.plot(x, x, 'bo')
plt.plot(x, x**2, color='#e35f62', marker='*', linewidth=2)
plt.plot(x, x**3, color='forestgreen', marker='^', markersize=9)

plt.tick_params(axis='both', direction='in', length=3, pad=6, labelsize=14)
title_right = plt.title('Graph Title', loc='right', pad=20)

title_font = {
    'fontsize':16,
    'fontweight':'bold'
}

title_left = plt.title('Graph Title', fontdict=title_font, loc='left', pad=20)

print(title_left.get_position()) #텍스트 위치, 문자열 얻기
print(title_left.get_text())

print(title_right.get_position())
print(title_right.get_text())

plt.show()
# Out:
# (0.0, 1.0)
# Graph Title
# (1.0, 1.0)
# Graph Title
